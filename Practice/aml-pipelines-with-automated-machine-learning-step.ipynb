# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-automated-machine-learning-step.png)

# %% [markdown]
# # Azure Machine Learning Pipeline with AutoMLStep (Udacity Course 2)
# This notebook demonstrates the use of AutoMLStep in Azure Machine Learning Pipeline.

# %% [markdown]
# ## Introduction
# In this example we showcase how you can use AzureML Dataset to load data for AutoML via AML Pipeline.
#
# If you are using an Azure Machine Learning Notebook VM, you are all set. Otherwise, make sure you have executed the [configuration](https://aka.ms/pl-config) before running this notebook.
#
# In this notebook you will learn how to:
# 1. Create an `Experiment` in an existing `Workspace`.
# 2. Create or Attach existing AmlCompute to a workspace.
# 3. Define data loading in a `TabularDataset`.
# 4. Configure AutoML using `AutoMLConfig`.
# 5. Use AutoMLStep
# 6. Train the model using AmlCompute
# 7. Explore the results.
# 8. Test the best fitted model.

# %% [markdown]
# ## Azure Machine Learning and Pipeline SDK-specific imports

# %%
import logging
import os
import csv

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.17.0

# %% [markdown]
# ## Initialize Workspace
# Initialize a workspace object from persisted configuration. Make sure the config file is present at .\config.json

# %%
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# quick-starts-ws-125359
# aml-quickstarts-125359
# southcentralus
# ebee3a56-4c54-406a-b732-174015826780

# %% [markdown]
# ## Create an Azure ML experiment
# Let's create an experiment named "automlstep-classification" and a folder to hold the training scripts. The script runs will be recorded under the experiment in Azure.
#
# The best practice is to use separate folders for scripts and its dependent files for each step and specify that folder as the `source_directory` for the step. This helps reduce the size of the snapshot created for the step (only the specific folder is snapshotted). Since changes in any files in the `source_directory` would trigger a re-upload of the snapshot, this helps keep the reuse of the step when there are no changes in the `source_directory` of the step.
#
# *Udacity Note:* There is no need to create an Azure ML experiment, this needs to re-use the experiment that was already created

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_name = 'ml-experiment-1'
project_folder = './pipeline-project'

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Experiment(Name: ml-experiment-1,
# Workspace: quick-starts-ws-125359)

# %% [markdown]
# ### Create or Attach an AmlCompute cluster
# You will need to create a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) for your AutoML run. In this tutorial, you get the default `AmlCompute` as your training compute resource.
#
# **Udacity Note** There is no need to create a new compute target, it can re-use the previous cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "auto-ml"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           max_nodes=4)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 10)
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Creating
# Succeeded..................................................................................................................
# AmlCompute wait for completion finished
#
# Wait timeout has been reached
# Current provisioning state of AmlCompute is "Succeeded" and current node count is "0"

# %% [markdown]
# ## Data
#
# **Udacity note:** Make sure the `key` is the same name as the dataset that is uploaded, and that the description matches. If it is hard to find or unknown, loop over the `ws.datasets.keys()` and `print()` them.
# If it *isn't* found because it was deleted, it can be recreated with the link that has the CSV

# %%
# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "BankMarketing Dataset"
description_text = "Bank Marketing DataSet for Udacity Course 2"

if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

if not found:
        # Create AML Dataset and register it into Workspace
        example_data = 'https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv'
        dataset = Dataset.Tabular.from_delimited_files(example_data)        
        #Register Dataset in Workspace
        dataset = dataset.register(workspace=ws,
                                   name=key,
                                   description=description_text)


df = dataset.to_pandas_dataframe()
df.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.040212    257.335205      2.561730    962.174780      0.174780
# std       10.432313    257.331700      2.763646    187.646785      0.496503
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    318.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  32950.000000    32950.000000   32950.000000  32950.000000  32950.000000
# mean       0.076228       93.574243     -40.518680      3.615654   5166.859608
# std        1.572242        0.578636       4.623004      1.735748     72.208448
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# ### Review the Dataset Result
#
# You can peek the result of a TabularDataset at any range using `skip(i)` and `take(j).to_pandas_dataframe()`. Doing so evaluates only `j` records for all the steps in the TabularDataset, which makes it fast even against large datasets.
#
# `TabularDataset` objects are composed of a list of transformation steps (optional).

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   57   technician  married  high.school       no      no  yes   cellular
# 1   55      unknown  married      unknown  unknown     yes   no  telephone
# 2   33  blue-collar  married     basic.9y       no      no   no   cellular
# 3   36       admin.  married  high.school       no      no   no  telephone
# 4   27    housemaid  married  high.school       no     yes   no   cellular
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure         -1.8
# 1   may         thu  ...         2    999         0  nonexistent          1.1
# 2   may         fri  ...         1    999         1      failure         -1.8
# 3   jun         fri  ...         4    999         0  nonexistent          1.4
# 4   jul         fri  ...         2    999         0  nonexistent          1.4
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.299       5099.1  no
# 1          93.994          -36.4      4.860       5191.0  no
# 2          92.893          -46.2      1.313       5099.1  no
# 3          94.465          -41.8      4.967       5228.1  no
# 4          93.918          -42.7      4.963       5228.1  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Train
# This creates a general AutoML settings object.
# **Udacity notes:** These inputs must match what was used when training in the portal. `label_column_name` has to be `y` for example.

# %%
automl_settings = {
    "experiment_timeout_minutes": 20,
    "max_concurrent_iterations": 5,
    "primary_metric" : 'AUC_weighted'
}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=dataset,
                             label_column_name="y",   
                             path = project_folder,
                             enable_early_stopping= True,
                             featurization= 'auto',
                             debug_log = "automl_errors.log",
                             **automl_settings
                            )

# %% [markdown]
# #### Create Pipeline and AutoMLStep
#
# You can define outputs for the AutoMLStep using TrainingOutput.

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %% [markdown]
# Create an AutoMLStep.

# %%
automl_step = AutoMLStep(
    name='automl_module',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %%
pipeline_run = experiment.submit(pipeline)
# Out:
# Created step automl_module [6eef79cf][818bab2e-df05-42e4-b300-adc6d52741ec], (This step will run and generate new outputs)
# Submitted PipelineRun 69d2b303-b727-4220-b908-2cf11ae1e01b
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/ml-experiment-1/runs/69d2b303-b727-4220-b908-2cf11ae1e01b?wsid=/subscriptions/ebee3a56-4c54-406a-b732-174015826780/resourcegroups/aml-quickstarts-125359/workspaces/quick-starts-ws-125359

# %%
from azureml.widgets import RunDetails
RunDetails(pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
pipeline_run.wait_for_completion()
# Out:
# PipelineRunId: 69d2b303-b727-4220-b908-2cf11ae1e01b
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/ml-experiment-1/runs/69d2b303-b727-4220-b908-2cf11ae1e01b?wsid=/subscriptions/ebee3a56-4c54-406a-b732-174015826780/resourcegroups/aml-quickstarts-125359/workspaces/quick-starts-ws-125359
# PipelineRun Status: Running
#
#
# StepRunId: 82ad160c-ab75-46ca-bad6-aff2a3c5f13d
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/ml-experiment-1/runs/82ad160c-ab75-46ca-bad6-aff2a3c5f13d?wsid=/subscriptions/ebee3a56-4c54-406a-b732-174015826780/resourcegroups/aml-quickstarts-125359/workspaces/quick-starts-ws-125359
# StepRun( automl_module ) Status: Running
#
# StepRun(automl_module) Execution Summary
# =========================================
# StepRun( automl_module ) Status: Finished
# {'runId': '82ad160c-ab75-46ca-bad6-aff2a3c5f13d', 'target': 'auto-ml', 'status': 'Completed', 'startTimeUtc': '2020-11-09T07:24:56.387879Z', 'endTimeUtc': '2020-11-09T08:04:01.971269Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': 'b2a75e78-9072-463b-9f9c-1a489f56f581', 'StepType': 'AutoMLStep', 'azureml.moduleid': '818bab2e-df05-42e4-b300-adc6d52741ec', 'azureml.nodeid': '6eef79cf', 'azureml.pipelinerunid': '69d2b303-b727-4220-b908-2cf11ae1e01b', 'num_iterations': '1000', 'training_type': 'TrainFull', 'acquisition_function': 'EI', 'metrics': 'accuracy', 'primary_metric': 'AUC_weighted', 'train_split': '0', 'MaxTimeSeconds': None, 'acquisition_parameter': '0', 'num_cross_validation': None, 'target': 'auto-ml', 'RawAMLSettingsString': None, 'AMLSettingsJsonString': '{"path": null, "name": "placeholder", "subscription_id": "ebee3a56-4c54-406a-b732-174015826780", "resource_group": "aml-quickstarts-125359", "workspace_name": "quick-starts-ws-125359", "region": "southcentralus", "compute_target": "auto-ml", "spark_service": null, "azure_service": null, "_local_managed_run_id": null, "many_models": false, "pipeline_fetch_max_batch_size": 1, "iterations": 1000, "primary_metric": "AUC_weighted", "task_type": "classification", "data_script": null, "validation_size": 0.0, "n_cross_validations": null, "y_min": null, "y_max": null, "num_classes": null, "featurization": "auto", "_ignore_package_version_incompatibilities": false, "is_timeseries": false, "max_cores_per_iteration": 1, "max_concurrent_iterations": 5, "iteration_timeout_minutes": null, "mem_in_mb": null, "enforce_time_on_windows": false, "experiment_timeout_minutes": 20, "experiment_exit_score": null, "whitelist_models": null, "blacklist_algos": null, "supported_models": ["LinearSVM", "SGD", "RandomForest", "XGBoostClassifier", "BernoulliNaiveBayes", "AveragedPerceptronClassifier", "LogisticRegression", "LightGBM", "TensorFlowLinearClassifier", "MultinomialNaiveBayes", "GradientBoosting", "ExtremeRandomTrees", "TensorFlowDNN", "DecisionTree", "SVM", "KNN"], "auto_blacklist": true, "blacklist_samples_reached": false, "exclude_nan_labels": true, "verbosity": 20, "_debug_log": "automl_errors.log", "show_warnings": false, "model_explainability": true, "service_url": null, "sdk_url": null, "sdk_packages": null, "enable_onnx_compatible_models": false, "enable_split_onnx_featurizer_estimator_models": false, "vm_type": "STANDARD_D2_V2", "telemetry_verbosity": 20, "send_telemetry": true, "enable_dnn": false, "force_text_dnn": false, "enable_feature_sweeping": true, "enable_early_stopping": true, "early_stopping_n_iters": 10, "metrics": null, "enable_ensembling": true, "enable_stack_ensembling": true, "ensemble_iterations": 15, "enable_tf": false, "enable_subsampling": null, "subsample_seed": null, "enable_nimbusml": false, "enable_streaming": false, "force_streaming": false, "track_child_runs": true, "allowed_private_models": [], "label_column_name": "y", "weight_column_name": null, "cv_split_column_names": null, "enable_local_managed": false, "cost_mode": 1, "lag_length": 0, "metric_operation": "maximize", "preprocess": true, "scenario": "SDK-1.13.0"}', 'DataPrepJsonString': '{\\"training_data\\": {\\"datasetId\\": \\"a651e109-2f17-48d9-a575-3a5c5bde4939\\"}, \\"datasets\\": 0}', 'EnableSubsampling': 'False', 'runTemplate': 'AutoML', 'Orchestrator': 'automl', 'ClientType': 'Others', '_aml_system_scenario_identification': 'Remote.Parent', 'root_attribution': 'azureml.StepRun', 'snapshotId': 'b2a75e78-9072-463b-9f9c-1a489f56f581', 'SetupRunId': '82ad160c-ab75-46ca-bad6-aff2a3c5f13d_setup', 'SetupRunContainerId': 'dcid.82ad160c-ab75-46ca-bad6-aff2a3c5f13d_setup', 'ClientSdkVersion': '1.17.0', 'FeaturizationRunJsonPath': 'featurizer_container.json', 'FeaturizationRunId': '82ad160c-ab75-46ca-bad6-aff2a3c5f13d_featurize', 'ProblemInfoJsonString': '{"dataset_num_categorical": 0, "is_sparse": true, "subsampling": false, "dataset_classes": 2, "dataset_features": 1 ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '69d2b303-b727-4220-b908-2cf11ae1e01b', 'status': 'Completed', 'startTimeUtc': '2020-11-09T07:24:22.687165Z', 'endTimeUtc': '2020-11-09T08:06:24.533214Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlstrg125359.blob.core.windows.net/azureml/ExperimentRun/dcid.69d2b303-b727-4220-b908-2cf11ae1e01b/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=MgZFYPLXEbrTGCKAr0A0YhGIUk7G0R9iU6%2FBHF88ARQ%3D&st=2020-11-09T07%3A14%3A51Z&se=2020-11-09T15%3A24%3A51Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlstrg125359.blob.core.windows.net/azureml/ExperimentRun/dcid.69d2b303-b727-4220-b908-2cf11ae1e01b/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=ZqFZGk%2FgGG5WT%2BSckVcGaD3K%2BzIJox8qKKiwRXXdOHw%3D&st=2020-11-09T07%3A14%3A51Z&se=2020-11-09T15%3A24%3A51Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlstrg125359.blob.core.windows.net/azureml/ExperimentRun/dcid.69d2b303-b727-4220-b908-2cf11ae1e01b/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=xexyCpiI8vXMqPSoahJxx1VShOs2VW9pft94M3YEYaY%3D&st=2020-11-09T07%3A14%3A51Z&se=2020-11-09T15%3A24%3A51Z&sp=r'}}
# 'Finished'

# %% [markdown]
# ## Examine Results
#
# ### Retrieve the metrics of all child runs
# Outputs of above run can be used as inputs of other steps in pipeline. In this tutorial, we will examine the outputs by retrieve output data and running some tests.

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('.', show_progress=True)
# Out:
# Downloading azureml/82ad160c-ab75-46ca-bad6-aff2a3c5f13d/metrics_data
# Downloaded azureml/82ad160c-ab75-46ca-bad6-aff2a3c5f13d/metrics_data, 1 files out of an estimated total of 1

# %%
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
#                                  82ad160c-ab75-46ca-bad6-aff2a3c5f13d_2  \
# AUC_macro                                          [0.8958714228290607]
# f1_score_macro                                     [0.5543982774496188]
# average_precision_score_micro                      [0.9678382447793712]
# accuracy                                           [0.8952959028831563]
# f1_score_weighted                                  [0.8568532490781945]
# precision_score_micro                              [0.8952959028831563]
# f1_score_micro                                     [0.8952959028831563]
# norm_macro_recall                                 [0.08872328641263172]
# AUC_micro                                          [0.9668783115079869]
# recall_score_weighted                              [0.8952959028831563]
# average_precision_score_weighted                   [0.9307932049953077]
# recall_score_micro                                 [0.8952959028831563]
# average_precision_score_macro                      [0.7419870399508339]
# recall_score_macro                                 [0.5443616432063159]
# precision_score_weighted                           [0.8830428100499781]
# AUC_weighted                                       [0.8958714228290606]
# balanced_accuracy                                  [0.5443616432063159]
# matthews_correlation                              [0.24375478015504795]
# precision_score_macro                              [0.8348410279354603]
# log_loss                                          [0.24981792864084124]
# weighted_accuracy                                  [0.9824233869498118]
#
#                                  82ad160c-ab75-46ca-bad6-aff2a3c5f13d_12  \
# AUC_macro                                           [0.9149268218587858]
# f1_score_macro                                      [0.6376634994605743]
# average_precision_score_micro                       [0.9721165833903395]
# accuracy                                             [0.898937784522003]
# f1_score_weighted                                   [0.8764334590395855]
# precision_score_micro                                [0.898937784522003]
# f1_score_micro                                      [0.8989377845220029]
# norm_macro_recall                                  [0.20650110123794319]
# AUC_micro                                           [0.9717418906192075]
# recall_score_weighted                                [0.898937784522003]
# average_precision_score_weighted                    [0.9387738403703894]
# recall_score_micro                                   [0.898937784522003]
# average_precision_score_macro                       [0.7683641909668164]
# recall_score_macro                                  [0.6032505506189716]
# precision_score_weighted                            [0.8792808912255702]
# AUC_weighted                                         [0.914926821858786]
# balanced_accuracy                                   [0.6032505506189716]
# matthews_correlation                               [0.33701070749824436]
# precision_score_macro                               [0.7750014801073571]
# log_loss                                            [0.2500720555436938]
# weighted_accuracy                                   [0.9723489264957829]
#
#                                  82ad160c-ab75-46ca-bad6-aff2a3c5f13d_24  \
# AUC_macro                                           [0.9402691873808691]
# f1_score_macro                                      [0.7691825165821541]
# average_precision_score_micro                       [0.9792423403521983]
# accuracy                                            [0.9128983308042489]
# f1_score_weighted                                   [0.9105214923382681]
# precision_score_micro                               [0.9128983308042489]
# f1_score_micro                                      [0.9128983308042489]
# norm_macro_recall                                   [0.5111503814969796]
# AUC_micro                                           [0.9782576718760432]
# recall_score_weighted                               [0.9128983308042489]
# average_precision_score_weighted                    [0.9518344397613885]
# recall_score_micro                                  [0.9128983308042489]
# average_precision_score_macro                       [0.8117468850807403]
# recall_score_macro                                  [0.7555751907484898]
# precision_score_weighted                             [0.908739808485468]
# AUC_weighted                                        [0.9402691873808691]
# balanced_accuracy                                   [0.7555751907484898]
# matthews_correlation                                [0.5398649524892071]
# precision_score_macro                               [0.7850963018677666]
# log_loss                                           [0.19211075143224646]
# weighted_accuracy                                    [0.951957410961161]
#
#                                  82ad160c-ab75-46ca-bad6-aff2a3c5f13d_6  \
# AUC_macro                                          [0.8960969496913015]
# f1_score_macro                                     [0.6267831475663812]
# average_precision_score_micro                       [0.967641685200761]
# accuracy                                           [0.9001517450682853]
# f1_score_weighted                                  [0.8746567304785686]
# precision_score_micro                              [0.9001517450682853]
# f1_score_micro                                     [0.9001517450682853]
# norm_macro_recall                                  [0.1865537828310615]
# AUC_micro                                          [0.9671836437698172]
# recall_score_weighted                              [0.9001517450682853]
# average_precision_score_weighted                   [0.9281473137995805]
# recall_score_micro                                 [0.9001517450682853]
# average_precision_score_macro                      [0.7302024136653613]
# recall_score_macro                                 [0.5932768914155307]
# precision_score_weighted                           [0.8827113977984437]
# AUC_weighted                                       [0.8960969496913014]
# balanced_accuracy                                  [0.5932768914155307]
# matthews_correlation                              [0.33340661446628406]
# precision_score_macro                              [0.7979300898726163]
# log_loss                                          [0.24828436238359022]
# weighted_accuracy                                  [0.9763404704059276]
#
#                                  82ad160c-ab75-46ca-bad6-aff2a3c5f13d_17  \
# AUC_macro                                           [0.9061372944556513]
# f1_score_macro                                      [0.6649517001692201]
# average_precision_score_micro                       [0.9699624643478723]
# accuracy                                            [0.8983308042488619]
# f1_score_weighted                                    [0.881951834398909]
# precision_score_micro                               [0.8983308042488619]
# f1_score_micro                                      [0.8983308042488619]
# norm_macro_recall                                   [0.2602876370527205]
# AUC_micro                                            [0.969061414153509]
# recall_score_weighted                               [0.8983308042488619]
# average_precision_score_weighted                      [0.93370550612276]
# recall_score_micro                                  [0.8983308042488619]
# average_precision_score_macro                       [0.7488894743032309]
# recall_score_macro                                  [0.6301438185263603]
# precision_score_weighted                            [0.8796594994186326]
# AUC_weighted                                        [0.9061372944556513]
# balanced_accuracy                                   [0.6301438185263603]
# matthews_correlation                               [0.36503950217538195]
# precision_score_macro                               [0.7559741977323734]
# log_loss                                            [0.2331431418265208]
# weighted_accuracy                                   [0.9649143784685428]
#
#                                  82ad160c-ab75-46ca-bad6-aff2a3c5f13d_18  \
# AUC_macro                                           [0.9052120322980401]
# f1_score_macro                                      [0.7174352900474987]
# average_precision_score_micro                       [0.8722545926115993]
# accuracy                                            [0.8406676783004552]
# f1_score_weighted                                   [0.8622446727509958]
# precision_score_micro                               [0.8406676783004552]
# f1_score_micro                                      [0.8406676783004552]
# norm_macro_recall                                   [0.6500591834353067]
# AUC_micro                                           [0.8981731183266135]
# recall_score_weighted                               [0.8406676783004552]
# average_precision_score_weighted                     [0.935678637595695]
# recall_score_micro                                  [0.8406676783004552]
# average_precision_score_macro                       [0.7594027649570599]
# recall_score_macro                                  [0.8250295917176533]
# precision_score_weighted                            [0.9072367884900322]
# AUC_weighted                                        [0.9052120322980401]
# balanced_accuracy                                   [0.8250295917176533]
# matthews_correlation                               [0.48890977108285155]
# precision_score_macro                               [0.6838546168958743]
# log_loss                                            [0.4259960077608569]
# weighted_accuracy                                   [0.8445501921958805]
#
#                                  82ad160c-ab75-46ca-bad6-aff2a3c5f13d_23  \
# AUC_macro                                           [0.8775787399022316]
# f1_score_macro                                      [0.6249203169110282]
# average_precision_score_micro                       [0.9642423601893725]
# accuracy                                            [0.8998482549317147]
# f1_score_weighted                                   [0.8741194440003212]
# precision_score_micro                               [0.8998482549317147]
# f1_score_micro                                      [0.8998482549317147]
# norm_macro_recall                                  [0.18384375573079037]
# AUC_micro                                           [0.9635751967044379]
# recall_score_weighted                               [0.8998482549317147]
# average_precision_score_weighted                    [0.9268948191943516]
# recall_score_micro                                  [0.8998482549317147]
# average_precision_score_macro                       [0.7361213218967824]
# recall_score_macro                                  [0.5919218778653952]
# precision_score_weighted                            [0.8821268229964793]
# AUC_weighted                                        [0.8775787399022316]
# balanced_accuracy                                   [0.5919218778653952]
# matthews_correlation                                [0.3300724193892132]
# precision_score_macro                               [0.7963054187192118]
# log_loss                                           [0.25566507368659297]
# weighted_accuracy                                   [0.9762980450897181]
#
#                                  82ad160c-ab75-46ca-bad6-aff2a3c5f13d_32  \
# AUC_macro                                           [0.9202561096014241]
# f1_score_macro                                       [0.698929803802615]
# average_precision_score_micro                       [0.9677812342585549]
# accuracy                                            [0.9031866464339909]
# f1_score_weighted                                   [0.8913707568639371]
# precision_score_micro                               [0.9031866464339909]
# f1_score_micro                                      [0.9031866464339909]
# norm_macro_recall                                   [0.3273307066631841]
# AUC_micro                                           [0.9699640555308661]
# recall_score_weighted                               [0.9031866464339909]
# average_precision_score_weighted                    [0.9384648276388263]
# recall_score_micro                                  [0.9031866464339909]
# average_precision_score_macro                       [0.7626804147464732]
# recall_score_macro                                   [0.663665353331592]
# precision_score_weighted                            [0.8886598373043313]
# AUC_weighted                                        [0.9202561096014241]
# balanced_accuracy                                    [0.663665353331592]
# matthews_correlation                                [0.4207095778234261]
# precision_score_macro                               [0.7703634967166262]
# log_loss                                            [0.2255348409857278]
# weighted_accuracy                                   [0.9626533045699655]
#
#                                  82ad160c-ab75-46ca-bad6-aff2a3c5f13d_31  \
# AUC_macro                                           [0.9444009135921845]
# f1_score_macro                                      [0.7739510013191502]
# average_precision_score_micro                       [0.9803672686898925]
# accuracy                                            [0.9150227617602428]
# f1_score_weighted                                   [0.9125297533160284]
# precision_score_micro                               [0.9150227617602428]
# f1_score_micro                                      [0.9150227617602428]
# norm_macro_recall                                   [0.5182792531958129]
# AUC_micro                                           [0.9794055922317577]
# recall_score_weighted                               [0.9150227617602428]
# average_precision_score_weighted                    [0.9521757313222089]
# recall_score_micro                                  [0.9150227617602428]
# average_precision_score_macro                       [0.8110321176902837]
# recall_score_macro                                  [0.7591396265979065]
# precision_score_weighted                            [0.9107315148757672]
# AUC_weighted                                        [0.9444009135921847]
# balanced_accuracy                                   [0.7591396265979065]
# matthews_correlation                                [0.5496528758240327]
# precision_score_macro                               [0.7914628378800695]
# log_loss                                           [0.18027994959633623]
# weighted_accuracy                                   [0.9537243276535915]
#
#                                  82ad160c-ab75-46ca-bad6-aff2a3c5f13d_33  ...  \
# AUC_macro                                           [0.9235477829829564]  ...
# f1_score_macro                                      [0.7310944783320217]  ...
# average_precision_score_micro                       [0.8846411994924759]  ...
# accuracy                                             [0.844309559939302]  ...
# f1_score_weighted                                   [0.8664971741551346]  ...
# precision_score_micro                                [0.844309559939302]  ...
# f1_score_micro                                       [0.844309559939302]  ...
# norm_macro_recall                                   [0.7133669354465246]  ...
# AUC_micro                                            [0.911153285545534]  ...
# recall_score_weighted                                [0.844309559939302]  ...
# average_precision_score_weighted                    [0.9370997115818839]  ...
# recall_score_micro                                   [0.844309559939302]  ...
# average_precision_score_macro                       [0.7552064750403038]  ...
# recall_score_macro                                  [0.8566834677232623]  ...
# precision_score_weighted                            [0.9171256626812081]  ...
# AUC_weighted                                        [0.9235477829829564]  ...
# balanced_accuracy                                   [0.8566834677232623]  ...
# matthews_correlation                                [0.5273792571792039]  ...
# precision_score_macro                               [0.6949409673219554]  ...
# log_loss                                            [0.4022485297618151]  ...
# weighted_accuracy                                   [0.8412374533450867]  ...
#
#                                  82ad160c-ab75-46ca-bad6-aff2a3c5f13d_13  \
# AUC_macro                                           [0.8502895264769462]
# f1_score_macro                                      [0.5962622384558832]
# average_precision_score_micro                       [0.8037643314024797]
# accuracy                                            [0.7195751138088012]
# f1_score_weighted                                    [0.769414914061271]
# precision_score_micro                               [0.7195751138088012]
# f1_score_micro                                      [0.7195751138088013]
# norm_macro_recall                                   [0.4615937478581893]
# AUC_micro                                           [0.8310276526028079]
# recall_score_weighted                               [0.7195751138088012]
# average_precision_score_weighted                     [0.914496553354816]
# recall_score_micro                                  [0.7195751138088012]
# average_precision_score_macro                       [0.6936634563527642]
# recall_score_macro                                  [0.7307968739290946]
# precision_score_weighted                            [0.8777668320502615]
# AUC_weighted                                        [0.8502895264769462]
# balanced_accuracy                                   [0.7307968739290946]
# matthews_correlation                                [0.3083238109709445]
# precision_score_macro                               [0.6029732019256596]
# log_loss                                            [0.5780147083704236]
# weighted_accuracy                                   [0.7167890543144076]
#
#                                  82ad160c-ab75-46ca-bad6-aff2a3c5f13d_14  \
# AUC_macro                                           [0.8925565947388797]
# f1_score_macro                                      [0.4703423886834914]
# average_precision_score_micro                       [0.9664100549541843]
# accuracy                                            [0.8880121396054628]
# f1_score_weighted                                   [0.8353395018439429]
# precision_score_micro                               [0.8880121396054628]
# f1_score_micro                                      [0.8880121396054628]
# norm_macro_recall                                                  [0.0]
# AUC_micro                                           [0.9660889608341143]
# recall_score_weighted                               [0.8880121396054628]
# average_precision_score_weighted                    [0.9213253883813849]
# recall_score_micro                                  [0.8880121396054628]
# average_precision_score_macro                       [0.7009026249110397]
# recall_score_macro                                                 [0.5]
# precision_score_weighted                             [0.788565560086672]
# AUC_weighted                                        [0.8925565947388796]
# balanced_accuracy                                                  [0.5]
# matthews_correlation                                               [0.0]
# precision_score_macro                               [0.4440060698027314]
# log_loss                                            [0.2460158217422364]
# weighted_accuracy                                   [0.9843450583187134]
#
#                                  82ad160c-ab75-46ca-bad6-aff2a3c5f13d_25  \
# AUC_macro                                            [0.928018957223065]
# f1_score_macro                                      [0.6984859504990945]
# average_precision_score_micro                       [0.9759793337677238]
# accuracy                                            [0.9059180576631259]
# f1_score_weighted                                   [0.8925598246368291]
# precision_score_micro                               [0.9059180576631259]
# f1_score_micro                                      [0.9059180576631259]
# norm_macro_recall                                  [0.31856526015704456]
# AUC_micro                                           [0.9747672129335616]
# recall_score_weighted                               [0.9059180576631259]
# average_precision_score_weighted                    [0.9437895715623489]
# recall_score_micro                                  [0.9059180576631259]
# average_precision_score_macro                       [0.7814021206048251]
# recall_score_macro                                  [0.6592826300785223]
# precision_score_weighted                            [0.8915595716074957]
# AUC_weighted                                        [0.9280189572230652]
# balanced_accuracy                                   [0.6592826300785223]
# matthews_correlation                                [0.4278083003917206]
# precision_score_macro                               [0.7872565919363406]
# log_loss                                           [0.20375152641797037]
# weighted_accuracy                                   [0.9671509629569505]
#
#                                  82ad160c-ab75-46ca-bad6-aff2a3c5f13d_29  \
# AUC_macro                                           [0.8347466967492642]
# f1_score_macro                                      [0.4703423886834914]
# average_precision_score_micro                       [0.9412496806930306]
# accuracy                                            [0.8880121396054628]
# f1_score_weighted                                   [0.8353395018439429]
# precision_score_micro                               [0.8880121396054628]
# f1_score_micro                                      [0.8880121396054628]
# norm_macro_recall                                                  [0.0]
# AUC_micro                                           [0.9545909675993194]
# recall_score_weighted                               [0.8880121396054628]
# average_precision_score_weighted                    [0.8984264061046473]
# recall_score_micro                                  [0.8880121396054628]
# average_precision_score_macro                       [0.6734012959673402]
# recall_score_macro                                                 [0.5]
# precision_score_weighted                             [0.788565560086672]
# AUC_weighted                                        [0.8347466967492642]
# balanced_accuracy                                                  [0.5]
# matthews_correlation                                               [0.0]
# precision_score_macro                               [0.4440060698027314]
# log_loss                                           [0.35061573479867364]
# weighted_accuracy                                   [0.9843450583187134]
#
#                                  82ad160c-ab75-46ca-bad6-aff2a3c5f13d_38  \
# AUC_macro                                           [0.9458754054389484]
# f1_score_macro                                      [0.7696670971531565]
# average_precision_score_micro                       [0.9810429751596081]
# accuracy                                            [0.9156297420333839]
# f1_score_weighted                                   [0.9119570258450136]
# precision_score_micro                               [0.9156297420333839]
# f1_score_micro                                      [0.9156297420333839]
# norm_macro_recall                                   [0.4976484077896144]
# AUC_micro                                           [0.9801231000204936]
# recall_score_weighted                               [0.9156297420333839]
# average_precision_score_weighted                    [0.9545360846489842]
# recall_score_micro                                  [0.9156297420333839]
# average_precision_score_macro                        [0.820934773808062]
# recall_score_macro                                  [0.7488242038948072]
# precision_score_weighted                            [0.9097739024995958]
# AUC_weighted                                        [0.9458754054389484]
# balanced_accuracy                                   [0.7488242038948072]
# matthews_correlation                                [0.5430888093748866]
# precision_score_macro                               [0.7963391927428036]
# log_loss                                           [0.18041639883155622]
# weighted_accuracy                                   [0.9570430451397317]
#
#                                  82ad160c-ab75-46ca-bad6-aff2a3c5f13d_4  \
# AUC_macro                                          [0.9040385516637122]
# f1_score_macro                                     [0.6502005401248553]
# average_precision_score_micro                      [0.9648665531700918]
# accuracy                                           [0.9004552352048558]
# f1_score_weighted                                  [0.8798027128265278]
# precision_score_micro                              [0.9004552352048558]
# f1_score_micro                                     [0.9004552352048558]
# norm_macro_recall                                 [0.22715602754113662]
# AUC_micro                                          [0.9679358756197025]
# recall_score_weighted                              [0.9004552352048558]
# average_precision_score_weighted                   [0.9322152488547576]
# recall_score_micro                                 [0.9004552352048558]
# average_precision_score_macro                      [0.7551850939788194]
# recall_score_macro                                 [0.6135780137705683]
# precision_score_weighted                           [0.8820192907220409]
# AUC_weighted                                       [0.9040385516637122]
# balanced_accuracy                                  [0.6135780137705683]
# matthews_correlation                              [0.35636800991289996]
# precision_score_macro                              [0.7795394862816971]
# log_loss                                          [0.44886502778722265]
# weighted_accuracy                                  [0.9716790893894515]
#
#                                  82ad160c-ab75-46ca-bad6-aff2a3c5f13d_15  \
# AUC_macro                                           [0.9148828279123529]
# f1_score_macro                                      [0.6182592429328723]
# average_precision_score_micro                       [0.9724404283838893]
# accuracy                                            [0.9004552352048558]
# f1_score_weighted                                   [0.8729627911995373]
# precision_score_micro                               [0.9004552352048558]
# f1_score_micro                                      [0.9004552352048558]
# norm_macro_recall                                  [0.17268596472704312]
# AUC_micro                                            [0.971012409016282]
# recall_score_weighted                               [0.9004552352048558]
# average_precision_score_weighted                    [0.9373204088777034]
# recall_score_micro                                  [0.9004552352048558]
# average_precision_score_macro                       [0.7587028057882201]
# recall_score_macro                                  [0.5863429823635216]
# precision_score_weighted                            [0.8849377663606582]
# AUC_weighted                                        [0.9148828279123529]
# balanced_accuracy                                   [0.5863429823635216]
# matthews_correlation                                [0.3288177453045086]
# precision_score_macro                               [0.8130570275298369]
# log_loss                                            [0.2179396331494213]
# weighted_accuracy                                   [0.9784408109926871]
#
#                                  82ad160c-ab75-46ca-bad6-aff2a3c5f13d_22  \
# AUC_macro                                           [0.8093584849040563]
# f1_score_macro                                      [0.6155920614362862]
# average_precision_score_micro                       [0.8040327815436354]
# accuracy                                            [0.7487101669195751]
# f1_score_weighted                                    [0.791137701312908]
# precision_score_micro                               [0.7487101669195751]
# f1_score_micro                                      [0.7487101669195751]
# norm_macro_recall                                   [0.4683521442186396]
# AUC_micro                                           [0.8314181831579093]
# recall_score_weighted                               [0.7487101669195751]
# average_precision_score_weighted                    [0.9053412672968503]
# recall_score_micro                                  [0.7487101669195751]
# average_precision_score_macro                        [0.702310157182787]
# recall_score_macro                                  [0.7341760721093198]
# precision_score_weighted                            [0.8775671735496419]
# AUC_weighted                                        [0.8093584849040563]
# balanced_accuracy                                   [0.7341760721093198]
# matthews_correlation                                [0.3224381184870554]
# precision_score_macro                               [0.6109916347526511]
# log_loss                                            [0.5754517873906212]
# weighted_accuracy                                   [0.7523185895203491]
#
#                                  82ad160c-ab75-46ca-bad6-aff2a3c5f13d_26  \
# AUC_macro                                           [0.9155621870641126]
# f1_score_macro                                      [0.5754222807361551]
# average_precision_score_micro                       [0.9724067907767859]
# accuracy                                            [0.8952959028831563]
# f1_score_weighted                                   [0.8614071939633867]
# precision_score_micro                               [0.8952959028831563]
# f1_score_micro                                      [0.8952959028831563]
# norm_macro_recall                                  [0.11477418601937206]
# AUC_micro                                           [0.9711046994918037]
# recall_score_weighted                               [0.8952959028831563]
# average_precision_score_weighted                    [0.9364526949875956]
# recall_score_micro                                  [0.8952959028831563]
# average_precision_score_macro                       [0.7548910371263058]
# recall_score_macro                                   [0.557387093009686]
# precision_score_weighted                            [0.8752637723527483]
# AUC_weighted                                        [0.9155621870641125]
# balanced_accuracy                                    [0.557387093009686]
# matthews_correlation                               [0.25833816779623664]
# precision_score_macro                               [0.7907387595371491]
# log_loss                                           [0.22126921632655472]
# weighted_accuracy                                   [0.9791895200960906]
#
#                                  82ad160c-ab75-46ca-bad6-aff2a3c5f13d_39
# AUC_macro                                           [0.9449955265102891]
# f1_score_macro                                        [0.62539469394059]
# average_precision_score_micro                       [0.9785302568690686]
# accuracy                                            [0.9034901365705614]
# f1_score_weighted                                   [0.8758667076090778]
# precision_score_micro                               [0.9034901365705614]
# f1_score_micro                                      [0.9034901365705614]
# norm_macro_recall                                  [0.18084012692485096]
# AUC_micro                                           [0.9774019125865512]
# recall_score_weighted                               [0.9034901365705614]
# average_precision_score_weighted                    [0.9540326772675617]
# recall_score_micro                                  [0.9034901365705614]
# average_precision_score_macro                       [0.8191665008760851]
# recall_score_macro                                  [0.5904200634624255]
# precision_score_weighted                            [0.8937865685845561]
# AUC_weighted                                         [0.944995526510289]
# balanced_accuracy                                   [0.5904200634624255]
# matthews_correlation                               [0.35568728549038287]
# precision_score_macro                               [0.8497936193997764]
# log_loss                                           [0.23149362361331946]
# weighted_accuracy                                   [0.9812169673211241]
#
# [21 rows x 37 columns]

# %% [markdown]
# ### Retrieve the Best Model

# %%
# Retrieve best model from Pipeline Run
best_model_output = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model_output.download('.', show_progress=True)
# Out:
# Downloading azureml/82ad160c-ab75-46ca-bad6-aff2a3c5f13d/model_data
# Downloaded azureml/82ad160c-ab75-46ca-bad6-aff2a3c5f13d/model_data, 1 files out of an estimated total of 1

# %%
import pickle

with open(best_model_output._path_on_datastore, "rb" ) as f:
    best_model = pickle.load(f)
best_model
# Out:
# PipelineWithYTransformations(Pipeline={'memory': None,
#                                        'steps': [('datatransformer',
#                                                   DataTransformer(allow_chargram=None,
#                                                                   enable_dnn=None,
#                                                                   enable_feature_sweeping=None,
#                                                                   feature_sweeping_config=None,
#                                                                   feature_sweeping_timeout=None,
#                                                                   featurization_config=None,
#                                                                   force_text_dnn=None,
#                                                                   is_cross_validation=None,
#                                                                   is_onnx_compatible=None,
#                                                                   logger=None,
#                                                                   observer=None,
#                                                                   task=Non...
#                                                                                                                                    min_samples_split=0.01,
#                                                                                                                                    min_weight_fraction_leaf=0.0,
#                                                                                                                                    n_estimators=10,
#                                                                                                                                    n_jobs=1,
#                                                                                                                                    oob_score=False,
#                                                                                                                                    random_state=None,
#                                                                                                                                    verbose=0,
#                                                                                                                                    warm_start=False))],
#                                                                                                       verbose=False))],
#                                                                                 flatten_transform=None,
#                                                                                 weights=[0.4666666666666667,
#                                                                                          0.13333333333333333,
#                                                                                          0.06666666666666667,
#                                                                                          0.2,
#                                                                                          0.06666666666666667,
#                                                                                          0.06666666666666667]))],
#                                        'verbose': False},
#                              y_transformer={},
#                              y_transformer_name='LabelEncoder')

# %%
best_model.steps
# Out:
# [('datatransformer',
#   DataTransformer(allow_chargram=None, enable_dnn=None,
#                   enable_feature_sweeping=None, feature_sweeping_config=None,
#                   feature_sweeping_timeout=None, featurization_config=None,
#                   force_text_dnn=None, is_cross_validation=None,
#                   is_onnx_compatible=None, logger=None, observer=None, task=None,
#                   working_dir=None)),
#  ('prefittedsoftvotingclassifier',
#   PreFittedSoftVotingClassifier(classification_labels=None,
#                                 estimators=[('0',
#                                              Pipeline(memory=None,
#                                                       steps=[('maxabsscaler',
#                                                               MaxAbsScaler(copy=True)),
#                                                              ('lightgbmclassifier',
#                                                               LightGBMClassifier(boosting_type='gbdt',
#                                                                                  class_weight=None,
#                                                                                  colsample_bytree=1.0,
#                                                                                  importance_type='split',
#                                                                                  learning_rate=0.1,
#                                                                                  max_depth=-1,
#                                                                                  min_child_samples=20,
#                                                                                  min_child_weight=0.001,
#                                                                                  min_spl...
#                                                                                    min_impurity_split=None,
#                                                                                    min_samples_leaf=0.035789473684210524,
#                                                                                    min_samples_split=0.01,
#                                                                                    min_weight_fraction_leaf=0.0,
#                                                                                    n_estimators=10,
#                                                                                    n_jobs=1,
#                                                                                    oob_score=False,
#                                                                                    random_state=None,
#                                                                                    verbose=0,
#                                                                                    warm_start=False))],
#                                                       verbose=False))],
#                                 flatten_transform=None,
#                                 weights=[0.4666666666666667, 0.13333333333333333,
#                                          0.06666666666666667, 0.2,
#                                          0.06666666666666667,
#                                          0.06666666666666667]))]

# %% [markdown]
# ### Test the Model
# #### Load Test Data
# For the test data, it should have the same preparation step as the train data. Otherwise it might get failed at the preprocessing step.

# %%
dataset_test = Dataset.Tabular.from_delimited_files(path='https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv')
df_test = dataset_test.to_pandas_dataframe()
df_test = df_test[pd.notnull(df_test['y'])]

y_test = df_test['y']
X_test = df_test.drop(['y'], axis=1)

# %% [markdown]
# #### Testing Our Best Fitted Model
#
# We will use confusion matrix to see how our model works.

# %%
from sklearn.metrics import confusion_matrix
ypred = best_model.predict(X_test)
cm = confusion_matrix(y_test, ypred)

# %%
# Visualize the confusion matrix
pd.DataFrame(cm).style.background_gradient(cmap='Blues', low=0, high=0.9)
# Out:
# <style  type="text/css" >
#     #T_1e572006_2264_11eb_9b39_33a6b0e5d1farow0_col0 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_1e572006_2264_11eb_9b39_33a6b0e5d1farow0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1e572006_2264_11eb_9b39_33a6b0e5d1farow1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1e572006_2264_11eb_9b39_33a6b0e5d1farow1_col1 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }</style><table id="T_1e572006_2264_11eb_9b39_33a6b0e5d1fa" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1e572006_2264_11eb_9b39_33a6b0e5d1falevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_1e572006_2264_11eb_9b39_33a6b0e5d1farow0_col0" class="data row0 col0" >28803</td>
#                         <td id="T_1e572006_2264_11eb_9b39_33a6b0e5d1farow0_col1" class="data row0 col1" >455</td>
#             </tr>
#             <tr>
#                         <th id="T_1e572006_2264_11eb_9b39_33a6b0e5d1falevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_1e572006_2264_11eb_9b39_33a6b0e5d1farow1_col0" class="data row1 col0" >1144</td>
#                         <td id="T_1e572006_2264_11eb_9b39_33a6b0e5d1farow1_col1" class="data row1 col1" >2548</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Publish and run from REST endpoint
#
# Run the following code to publish the pipeline to your workspace. In your workspace in the portal, you can see metadata for the pipeline including run history and durations. You can also run the pipeline manually from the portal.
#
# Additionally, publishing the pipeline enables a REST endpoint to rerun the pipeline from any HTTP library on any platform.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="Bankmarketing Train", description="Training bankmarketing pipeline", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: Bankmarketing Train,
# Id: b9209d99-e7e7-4f3f-893b-caaa5b9df21f,
# Status: Active,
# Endpoint: https://southcentralus.api.azureml.ms/pipelines/v1.0/subscriptions/ebee3a56-4c54-406a-b732-174015826780/resourceGroups/aml-quickstarts-125359/providers/Microsoft.MachineLearningServices/workspaces/quick-starts-ws-125359/PipelineRuns/PipelineSubmit/b9209d99-e7e7-4f3f-893b-caaa5b9df21f)

# %% [markdown]
# Authenticate once again, to retrieve the `auth_header` so that the endpoint can be used

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Get the REST url from the endpoint property of the published pipeline object. You can also find the REST url in your workspace in the portal. Build an HTTP POST request to the endpoint, specifying your authentication header. Additionally, add a JSON payload object with the experiment name and the batch size parameter. As a reminder, the process_count_per_node is passed through to ParallelRunStep because you defined it is defined as a PipelineParameter object in the step configuration.
#
# Make the request to trigger the run. Access the Id key from the response dict to get the value of the run id.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "pipeline-rest-endpoint"}
                        )

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)
# Out:
# Submitted pipeline run:  6c79344e-6c35-4fac-819d-08c7a82f8616

# %% [markdown]
# Use the run id to monitor the status of the new run. This will take another 10-15 min to run and will look similar to the previous pipeline run, so if you don't need to see another pipeline run, you can skip watching the full output.

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["pipeline-rest-endpoint"], run_id)
RunDetails(published_pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

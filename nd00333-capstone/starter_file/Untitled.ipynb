# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Telco-Customer-Churn.csv")
df.sample(4)
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 5831  Female              0      No         No       9          Yes
# 2205    Male              1      No         No      34          Yes
# 1183  Female              0     Yes         No      53          Yes
# 1       Male              0      No         No      34          Yes
#
#      MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 5831            No     Fiber optic             No           No
# 2205            No     Fiber optic             No          Yes
# 1183            No     Fiber optic             No           No
# 1               No             DSL            Yes           No
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 5831               No          No         Yes             Yes  Month-to-month
# 2205              Yes          No         Yes             Yes        One year
# 1183               No         Yes         Yes             Yes        One year
# 1                 Yes          No          No              No        One year
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges  \
# 5831              Yes  Bank transfer (automatic)           90.80       809.75
# 2205              Yes           Electronic check           99.85      3343.15
# 1183              Yes           Electronic check           93.45       4872.2
# 1                  No               Mailed check           56.95       1889.5
#
#      Churn
# 5831   Yes
# 2205    No
# 1183    No
# 1       No

# %%
df.isna().sum() # No null values
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.shape
# Out:
# (7043, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
#  16  PaymentMethod     7043 non-null   object
#  17  MonthlyCharges    7043 non-null   float64
#  18  TotalCharges      7043 non-null   object
#  19  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(17)
# memory usage: 1.1+ MB

# %%
df['TotalCharges'] = pd.to_numeric(df.TotalCharges, errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
#  16  PaymentMethod     7043 non-null   object
#  17  MonthlyCharges    7043 non-null   float64
#  18  TotalCharges      7032 non-null   float64
#  19  Churn             7043 non-null   object
# dtypes: float64(2), int64(2), object(16)
# memory usage: 1.1+ MB

# %%
df.groupby(df['gender']).count()
# Out:
#         SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# gender
# Female           3488     3488        3488    3488          3488
# Male             3555     3555        3555    3555          3555
#
#         MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# gender
# Female           3488             3488            3488          3488
# Male             3555             3555            3555          3555
#
#         DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# gender
# Female              3488         3488         3488             3488      3488
# Male                3555         3555         3555             3555      3555
#
#         PaperlessBilling  PaymentMethod  MonthlyCharges  TotalCharges  Churn
# gender
# Female              3488           3488            3488          3483   3488
# Male                3555           3555            3555          3549   3555

# %%
df.groupby(df['SeniorCitizen']).count()
# Out:
#                gender  Partner  Dependents  tenure  PhoneService  \
# SeniorCitizen
# 0                5901     5901        5901    5901          5901
# 1                1142     1142        1142    1142          1142
#
#                MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# SeniorCitizen
# 0                       5901             5901            5901          5901
# 1                       1142             1142            1142          1142
#
#                DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# SeniorCitizen
# 0                          5901         5901         5901             5901
# 1                          1142         1142         1142             1142
#
#                Contract  PaperlessBilling  PaymentMethod  MonthlyCharges  \
# SeniorCitizen
# 0                  5901              5901           5901            5901
# 1                  1142              1142           1142            1142
#
#                TotalCharges  Churn
# SeniorCitizen
# 0                      5890   5901
# 1                      1142   1142

# %%
df.groupby(df['Partner']).count()
# Out:
#          gender  SeniorCitizen  Dependents  tenure  PhoneService  \
# Partner
# No         3641           3641        3641    3641          3641
# Yes        3402           3402        3402    3402          3402
#
#          MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# Partner
# No                3641             3641            3641          3641
# Yes               3402             3402            3402          3402
#
#          DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# Partner
# No                   3641         3641         3641             3641
# Yes                  3402         3402         3402             3402
#
#          Contract  PaperlessBilling  PaymentMethod  MonthlyCharges  \
# Partner
# No           3641              3641           3641            3641
# Yes          3402              3402           3402            3402
#
#          TotalCharges  Churn
# Partner
# No               3639   3641
# Yes              3393   3402

# %%
df['Partner'] = pd.Series(np.where(df.Partner.values == 'Yes',1,0))

# %%
df.groupby(df['Dependents']).count()
# Out:
#             gender  SeniorCitizen  Partner  tenure  PhoneService  \
# Dependents
# No            4933           4933     4933    4933          4933
# Yes           2110           2110     2110    2110          2110
#
#             MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# Dependents
# No                   4933             4933            4933          4933
# Yes                  2110             2110            2110          2110
#
#             DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# Dependents
# No                      4933         4933         4933             4933
# Yes                     2110         2110         2110             2110
#
#             Contract  PaperlessBilling  PaymentMethod  MonthlyCharges  \
# Dependents
# No              4933              4933           4933            4933
# Yes             2110              2110           2110            2110
#
#             TotalCharges  Churn
# Dependents
# No                  4933   4933
# Yes                 2099   2110

# %%
df['Dependents'] = pd.Series(np.where(df.Dependents.values == 'Yes',1,0))

# %%
df.groupby(df['Contract']).count()
# Out:
#                 gender  SeniorCitizen  Partner  Dependents  tenure  \
# Contract
# Month-to-month    3875           3875     3875        3875    3875
# One year          1473           1473     1473        1473    1473
# Two year          1695           1695     1695        1695    1695
#
#                 PhoneService  MultipleLines  InternetService  OnlineSecurity  \
# Contract
# Month-to-month          3875           3875             3875            3875
# One year                1473           1473             1473            1473
# Two year                1695           1695             1695            1695
#
#                 OnlineBackup  DeviceProtection  TechSupport  StreamingTV  \
# Contract
# Month-to-month          3875              3875         3875         3875
# One year                1473              1473         1473         1473
# Two year                1695              1695         1695         1695
#
#                 StreamingMovies  Contract  PaperlessBilling  PaymentMethod  \
# Contract
# Month-to-month             3875      3875              3875           3875
# One year                   1473      1473              1473           1473
# Two year                   1695      1695              1695           1695
#
#                 MonthlyCharges  TotalCharges  Churn
# Contract
# Month-to-month            3875          3875   3875
# One year                  1473          1472   1473
# Two year                  1695          1685   1695

# %%
df.groupby(df['PaymentMethod']).count()
# Out:
#                            gender  SeniorCitizen  Partner  Dependents  tenure  \
# PaymentMethod
# Bank transfer (automatic)    1544           1544     1544        1544    1544
# Credit card (automatic)      1522           1522     1522        1522    1522
# Electronic check             2365           2365     2365        2365    2365
# Mailed check                 1612           1612     1612        1612    1612
#
#                            PhoneService  MultipleLines  InternetService  \
# PaymentMethod
# Bank transfer (automatic)          1544           1544             1544
# Credit card (automatic)            1522           1522             1522
# Electronic check                   2365           2365             2365
# Mailed check                       1612           1612             1612
#
#                            OnlineSecurity  OnlineBackup  DeviceProtection  \
# PaymentMethod
# Bank transfer (automatic)            1544          1544              1544
# Credit card (automatic)              1522          1522              1522
# Electronic check                     2365          2365              2365
# Mailed check                         1612          1612              1612
#
#                            TechSupport  StreamingTV  StreamingMovies  \
# PaymentMethod
# Bank transfer (automatic)         1544         1544             1544
# Credit card (automatic)           1522         1522             1522
# Electronic check                  2365         2365             2365
# Mailed check                      1612         1612             1612
#
#                            Contract  PaperlessBilling  MonthlyCharges  \
# PaymentMethod
# Bank transfer (automatic)      1544              1544            1544
# Credit card (automatic)        1522              1522            1522
# Electronic check               2365              2365            2365
# Mailed check                   1612              1612            1612
#
#                            TotalCharges  Churn
# PaymentMethod
# Bank transfer (automatic)          1542   1544
# Credit card (automatic)            1521   1522
# Electronic check                   2365   2365
# Mailed check                       1604   1612

# %%
df.groupby(df['PaperlessBilling']).count()
# Out:
#                   gender  SeniorCitizen  Partner  Dependents  tenure  \
# PaperlessBilling
# No                  2872           2872     2872        2872    2872
# Yes                 4171           4171     4171        4171    4171
#
#                   PhoneService  MultipleLines  InternetService  \
# PaperlessBilling
# No                        2872           2872             2872
# Yes                       4171           4171             4171
#
#                   OnlineSecurity  OnlineBackup  DeviceProtection  TechSupport  \
# PaperlessBilling
# No                          2872          2872              2872         2872
# Yes                         4171          4171              4171         4171
#
#                   StreamingTV  StreamingMovies  Contract  PaymentMethod  \
# PaperlessBilling
# No                       2872             2872      2872           2872
# Yes                      4171             4171      4171           4171
#
#                   MonthlyCharges  TotalCharges  Churn
# PaperlessBilling
# No                          2872          2864   2872
# Yes                         4171          4168   4171

# %%
df['PaperlessBilling'] = pd.Series(np.where(df.PaperlessBilling.values == 'Yes',1,0))

# %% [markdown]
# ### Phone Service and MultipleLines Rectification

# %%
df.groupby(df['PhoneService']).count()
# Out:
#               gender  SeniorCitizen  Partner  Dependents  tenure  \
# PhoneService
# No               682            682      682         682     682
# Yes             6361           6361     6361        6361    6361
#
#               PhoneService  MultipleLines  InternetService  OnlineSecurity  \
# PhoneService
# No                     682            682              682             682
# Yes                   6361           6361             6361            6361
#
#               OnlineBackup  DeviceProtection  TechSupport  StreamingTV  \
# PhoneService
# No                     682               682          682          682
# Yes                   6361              6361         6361         6361
#
#               StreamingMovies  Contract  PaperlessBilling  PaymentMethod  \
# PhoneService
# No                        682       682               682            682
# Yes                      6361      6361              6361           6361
#
#               MonthlyCharges  TotalCharges  Churn
# PhoneService
# No                       682           680    682
# Yes                     6361          6352   6361

# %%
df['PhoneService'] = pd.Series(np.where(df.PhoneService.values == 'Yes',1,0))

# %%
df.groupby(df['PhoneService']).count()
# Out:
#               gender  SeniorCitizen  Partner  Dependents  tenure  \
# PhoneService
# 0                682            682      682         682     682
# 1               6361           6361     6361        6361    6361
#
#               PhoneService  MultipleLines  InternetService  OnlineSecurity  \
# PhoneService
# 0                      682            682              682             682
# 1                     6361           6361             6361            6361
#
#               OnlineBackup  DeviceProtection  TechSupport  StreamingTV  \
# PhoneService
# 0                      682               682          682          682
# 1                     6361              6361         6361         6361
#
#               StreamingMovies  Contract  PaperlessBilling  PaymentMethod  \
# PhoneService
# 0                         682       682               682            682
# 1                        6361      6361              6361           6361
#
#               MonthlyCharges  TotalCharges  Churn
# PhoneService
# 0                        682           680    682
# 1                       6361          6352   6361

# %%
df.groupby(df['MultipleLines']).count()
# Out:
#                   gender  SeniorCitizen  Partner  Dependents  tenure  \
# MultipleLines
# No                  3390           3390     3390        3390    3390
# No phone service     682            682      682         682     682
# Yes                 2971           2971     2971        2971    2971
#
#                   PhoneService  InternetService  OnlineSecurity  OnlineBackup  \
# MultipleLines
# No                        3390             3390            3390          3390
# No phone service           682              682             682           682
# Yes                       2971             2971            2971          2971
#
#                   DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# MultipleLines
# No                            3390         3390         3390             3390
# No phone service               682          682          682              682
# Yes                           2971         2971         2971             2971
#
#                   Contract  PaperlessBilling  PaymentMethod  MonthlyCharges  \
# MultipleLines
# No                    3390              3390           3390            3390
# No phone service       682               682            682             682
# Yes                   2971              2971           2971            2971
#
#                   TotalCharges  Churn
# MultipleLines
# No                        3385   3390
# No phone service           680    682
# Yes                       2967   2971

# %%
df['MultipleLines'] = pd.Series(np.where(df.MultipleLines.values == 'Yes',1,0))

# %%
df.groupby(df['MultipleLines']).count()
# Out:
#                gender  SeniorCitizen  Partner  Dependents  tenure  \
# MultipleLines
# 0                4072           4072     4072        4072    4072
# 1                2971           2971     2971        2971    2971
#
#                PhoneService  MultipleLines  InternetService  OnlineSecurity  \
# MultipleLines
# 0                      4072           4072             4072            4072
# 1                      2971           2971             2971            2971
#
#                OnlineBackup  DeviceProtection  TechSupport  StreamingTV  \
# MultipleLines
# 0                      4072              4072         4072         4072
# 1                      2971              2971         2971         2971
#
#                StreamingMovies  Contract  PaperlessBilling  PaymentMethod  \
# MultipleLines
# 0                         4072      4072              4072           4072
# 1                         2971      2971              2971           2971
#
#                MonthlyCharges  TotalCharges  Churn
# MultipleLines
# 0                        4072          4065   4072
# 1                        2971          2967   2971

# %% [markdown]
# ### Internet Service and
# * Online Security
# * Online Backup
# * Device Protection
# * TechSupport
# * Streaming Movies
# * Streaming TV
#  ### seems correlated

# %%
df.groupby(df['InternetService']).count()
# Out:
#                  gender  SeniorCitizen  Partner  Dependents  tenure  \
# InternetService
# DSL                2421           2421     2421        2421    2421
# Fiber optic        3096           3096     3096        3096    3096
# No                 1526           1526     1526        1526    1526
#
#                  PhoneService  MultipleLines  OnlineSecurity  OnlineBackup  \
# InternetService
# DSL                      2421           2421            2421          2421
# Fiber optic              3096           3096            3096          3096
# No                       1526           1526            1526          1526
#
#                  DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# InternetService
# DSL                          2421         2421         2421             2421
# Fiber optic                  3096         3096         3096             3096
# No                           1526         1526         1526             1526
#
#                  Contract  PaperlessBilling  PaymentMethod  MonthlyCharges  \
# InternetService
# DSL                  2421              2421           2421            2421
# Fiber optic          3096              3096           3096            3096
# No                   1526              1526           1526            1526
#
#                  TotalCharges  Churn
# InternetService
# DSL                      2416   2421
# Fiber optic              3096   3096
# No                       1520   1526

# %%
df.groupby(df['OnlineSecurity']).count()
# Out:
#                      gender  SeniorCitizen  Partner  Dependents  tenure  \
# OnlineSecurity
# No                     3498           3498     3498        3498    3498
# No internet service    1526           1526     1526        1526    1526
# Yes                    2019           2019     2019        2019    2019
#
#                      PhoneService  MultipleLines  InternetService  \
# OnlineSecurity
# No                           3498           3498             3498
# No internet service          1526           1526             1526
# Yes                          2019           2019             2019
#
#                      OnlineBackup  DeviceProtection  TechSupport  StreamingTV  \
# OnlineSecurity
# No                           3498              3498         3498         3498
# No internet service          1526              1526         1526         1526
# Yes                          2019              2019         2019         2019
#
#                      StreamingMovies  Contract  PaperlessBilling  \
# OnlineSecurity
# No                              3498      3498              3498
# No internet service             1526      1526              1526
# Yes                             2019      2019              2019
#
#                      PaymentMethod  MonthlyCharges  TotalCharges  Churn
# OnlineSecurity
# No                            3498            3498          3497   3498
# No internet service           1526            1526          1520   1526
# Yes                           2019            2019          2015   2019

# %%
df['OnlineSecurity'] = pd.Series(np.where(df.OnlineSecurity.values == 'Yes',1,0))

# %%
df.groupby(df['OnlineBackup']).count()
# Out:
#                      gender  SeniorCitizen  Partner  Dependents  tenure  \
# OnlineBackup
# No                     3088           3088     3088        3088    3088
# No internet service    1526           1526     1526        1526    1526
# Yes                    2429           2429     2429        2429    2429
#
#                      PhoneService  MultipleLines  InternetService  \
# OnlineBackup
# No                           3088           3088             3088
# No internet service          1526           1526             1526
# Yes                          2429           2429             2429
#
#                      OnlineSecurity  OnlineBackup  DeviceProtection  \
# OnlineBackup
# No                             3088          3088              3088
# No internet service            1526          1526              1526
# Yes                            2429          2429              2429
#
#                      TechSupport  StreamingTV  StreamingMovies  Contract  \
# OnlineBackup
# No                          3088         3088             3088      3088
# No internet service         1526         1526             1526      1526
# Yes                         2429         2429             2429      2429
#
#                      PaperlessBilling  PaymentMethod  MonthlyCharges  \
# OnlineBackup
# No                               3088           3088            3088
# No internet service              1526           1526            1526
# Yes                              2429           2429            2429
#
#                      TotalCharges  Churn
# OnlineBackup
# No                           3087   3088
# No internet service          1520   1526
# Yes                          2425   2429

# %%
df['OnlineBackup'] = pd.Series(np.where(df.OnlineBackup.values == 'Yes',1,0))

# %%
df.groupby(df['DeviceProtection']).count()
# Out:
#                      gender  SeniorCitizen  Partner  Dependents  tenure  \
# DeviceProtection
# No                     3095           3095     3095        3095    3095
# No internet service    1526           1526     1526        1526    1526
# Yes                    2422           2422     2422        2422    2422
#
#                      PhoneService  MultipleLines  InternetService  \
# DeviceProtection
# No                           3095           3095             3095
# No internet service          1526           1526             1526
# Yes                          2422           2422             2422
#
#                      OnlineSecurity  OnlineBackup  DeviceProtection  \
# DeviceProtection
# No                             3095          3095              3095
# No internet service            1526          1526              1526
# Yes                            2422          2422              2422
#
#                      TechSupport  StreamingTV  StreamingMovies  Contract  \
# DeviceProtection
# No                          3095         3095             3095      3095
# No internet service         1526         1526             1526      1526
# Yes                         2422         2422             2422      2422
#
#                      PaperlessBilling  PaymentMethod  MonthlyCharges  \
# DeviceProtection
# No                               3095           3095            3095
# No internet service              1526           1526            1526
# Yes                              2422           2422            2422
#
#                      TotalCharges  Churn
# DeviceProtection
# No                           3094   3095
# No internet service          1520   1526
# Yes                          2418   2422

# %%
df['DeviceProtection'] = pd.Series(np.where(df.DeviceProtection.values == 'Yes',1,0))

# %%
df.groupby(df['TechSupport']).count()
# Out:
#                      gender  SeniorCitizen  Partner  Dependents  tenure  \
# TechSupport
# No                     3473           3473     3473        3473    3473
# No internet service    1526           1526     1526        1526    1526
# Yes                    2044           2044     2044        2044    2044
#
#                      PhoneService  MultipleLines  InternetService  \
# TechSupport
# No                           3473           3473             3473
# No internet service          1526           1526             1526
# Yes                          2044           2044             2044
#
#                      OnlineSecurity  OnlineBackup  DeviceProtection  \
# TechSupport
# No                             3473          3473              3473
# No internet service            1526          1526              1526
# Yes                            2044          2044              2044
#
#                      TechSupport  StreamingTV  StreamingMovies  Contract  \
# TechSupport
# No                          3473         3473             3473      3473
# No internet service         1526         1526             1526      1526
# Yes                         2044         2044             2044      2044
#
#                      PaperlessBilling  PaymentMethod  MonthlyCharges  \
# TechSupport
# No                               3473           3473            3473
# No internet service              1526           1526            1526
# Yes                              2044           2044            2044
#
#                      TotalCharges  Churn
# TechSupport
# No                           3472   3473
# No internet service          1520   1526
# Yes                          2040   2044

# %%
df['TechSupport'] = pd.Series(np.where(df.TechSupport.values == 'Yes',1,0))

# %%
df.groupby(df['StreamingMovies']).count()
# Out:
#                      gender  SeniorCitizen  Partner  Dependents  tenure  \
# StreamingMovies
# No                     2785           2785     2785        2785    2785
# No internet service    1526           1526     1526        1526    1526
# Yes                    2732           2732     2732        2732    2732
#
#                      PhoneService  MultipleLines  InternetService  \
# StreamingMovies
# No                           2785           2785             2785
# No internet service          1526           1526             1526
# Yes                          2732           2732             2732
#
#                      OnlineSecurity  OnlineBackup  DeviceProtection  \
# StreamingMovies
# No                             2785          2785              2785
# No internet service            1526          1526              1526
# Yes                            2732          2732              2732
#
#                      TechSupport  StreamingTV  StreamingMovies  Contract  \
# StreamingMovies
# No                          2785         2785             2785      2785
# No internet service         1526         1526             1526      1526
# Yes                         2732         2732             2732      2732
#
#                      PaperlessBilling  PaymentMethod  MonthlyCharges  \
# StreamingMovies
# No                               2785           2785            2785
# No internet service              1526           1526            1526
# Yes                              2732           2732            2732
#
#                      TotalCharges  Churn
# StreamingMovies
# No                           2781   2785
# No internet service          1520   1526
# Yes                          2731   2732

# %%
df['StreamingMovies'] = pd.Series(np.where(df.StreamingMovies.values == 'Yes',1,0))

# %%
df.groupby(df['StreamingTV']).count()
# Out:
#                      gender  SeniorCitizen  Partner  Dependents  tenure  \
# StreamingTV
# No                     2810           2810     2810        2810    2810
# No internet service    1526           1526     1526        1526    1526
# Yes                    2707           2707     2707        2707    2707
#
#                      PhoneService  MultipleLines  InternetService  \
# StreamingTV
# No                           2810           2810             2810
# No internet service          1526           1526             1526
# Yes                          2707           2707             2707
#
#                      OnlineSecurity  OnlineBackup  DeviceProtection  \
# StreamingTV
# No                             2810          2810              2810
# No internet service            1526          1526              1526
# Yes                            2707          2707              2707
#
#                      TechSupport  StreamingTV  StreamingMovies  Contract  \
# StreamingTV
# No                          2810         2810             2810      2810
# No internet service         1526         1526             1526      1526
# Yes                         2707         2707             2707      2707
#
#                      PaperlessBilling  PaymentMethod  MonthlyCharges  \
# StreamingTV
# No                               2810           2810            2810
# No internet service              1526           1526            1526
# Yes                              2707           2707            2707
#
#                      TotalCharges  Churn
# StreamingTV
# No                           2809   2810
# No internet service          1520   1526
# Yes                          2703   2707

# %%
df['StreamingTV'] = pd.Series(np.where(df.StreamingTV.values == 'Yes',1,0))

# %%
df.sample(10)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 1809    Male              1        1           0      32             1
# 2334    Male              1        1           0      16             1
# 2903    Male              0        1           1      12             0
# 146     Male              0        0           0       3             1
# 6682    Male              0        1           0      69             1
# 3186  Female              0        1           1      58             1
# 1070  Female              0        0           0       2             1
# 6975  Female              0        1           1      24             1
# 1911  Female              0        1           1      72             1
# 4473  Female              1        1           0      26             1
#
#       MultipleLines InternetService  OnlineSecurity  OnlineBackup  \
# 1809              1     Fiber optic               0             0
# 2334              1     Fiber optic               0             0
# 2903              0             DSL               0             1
# 146               0              No               0             0
# 6682              1     Fiber optic               0             1
# 3186              0              No               0             0
# 1070              0     Fiber optic               0             0
# 6975              1             DSL               1             1
# 1911              1     Fiber optic               1             1
# 4473              1     Fiber optic               0             0
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# 1809                 0            0            0                1
# 2334                 0            0            1                0
# 2903                 0            1            0                0
# 146                  0            0            0                0
# 6682                 0            1            1                0
# 3186                 0            0            0                0
# 1070                 0            0            0                0
# 6975                 1            0            0                0
# 1911                 1            1            1                0
# 4473                 1            0            1                1
#
#             Contract  PaperlessBilling              PaymentMethod  \
# 1809  Month-to-month                 1           Electronic check
# 2334  Month-to-month                 1    Credit card (automatic)
# 2903  Month-to-month                 0               Mailed check
# 146         One year                 0               Mailed check
# 6682        Two year                 1               Mailed check
# 3186        Two year                 0    Credit card (automatic)
# 1070  Month-to-month                 0  Bank transfer (automatic)
# 6975        Two year                 0           Electronic check
# 1911        Two year                 0    Credit card (automatic)
# 4473  Month-to-month                 1  Bank transfer (automatic)
#
#       MonthlyCharges  TotalCharges Churn
# 1809           85.00       2642.05   Yes
# 2334           85.05       1391.15    No
# 2903           35.50        432.25    No
# 146            19.60         61.35    No
# 6682           92.45       6460.55    No
# 3186           20.30       1160.75    No
# 1070           69.75        144.55   Yes
# 6975           64.35       1558.65    No
# 1911          106.10       7657.40    No
# 4473           98.10       2510.70    No

# %% [markdown]
# ### Encoding

# %%
df = pd.get_dummies(df,columns=['gender'],drop_first= True)
df = pd.get_dummies(df,columns=['InternetService'],drop_first= True)
df = pd.get_dummies(df,columns=['PaymentMethod'],drop_first= False)

# %%
#df = pd.get_dummies(df,columns=['Contract'],drop_first= True, prefix="contract")
df.sample(5)
# Out:
#       SeniorCitizen  Partner  Dependents  tenure  PhoneService  MultipleLines  \
# 5853              0        1           0      62             1              1
# 2891              0        0           0       1             1              0
# 5354              0        0           1       1             1              0
# 1902              0        1           1      72             1              1
# 1430              0        0           0      23             1              1
#
#       OnlineSecurity  OnlineBackup  DeviceProtection  TechSupport  ...  \
# 5853               1             1                 0            0  ...
# 2891               0             0                 0            0  ...
# 5354               0             0                 0            0  ...
# 1902               1             1                 1            1  ...
# 1430               0             0                 0            0  ...
#
#       MonthlyCharges  TotalCharges Churn  gender_Male  \
# 5853           96.10       6001.45    No            1
# 2891           79.70         79.70   Yes            0
# 5354           89.35         89.35    No            0
# 1902           90.60       6441.85    No            1
# 1430           24.80        615.35    No            0
#
#       InternetService_Fiber optic  InternetService_No  \
# 5853                            1                   0
# 2891                            1                   0
# 5354                            1                   0
# 1902                            0                   0
# 1430                            0                   1
#
#      PaymentMethod_Bank transfer (automatic)  \
# 5853                                       0
# 2891                                       0
# 5354                                       0
# 1902                                       0
# 1430                                       0
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 5853                                      0                               1
# 2891                                      0                               1
# 5354                                      0                               1
# 1902                                      1                               0
# 1430                                      1                               0
#
#       PaymentMethod_Mailed check
# 5853                           0
# 2891                           0
# 5354                           0
# 1902                           0
# 1430                           0
#
# [5 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 24 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   SeniorCitizen                            7043 non-null   int64
#  1   Partner                                  7043 non-null   int32
#  2   Dependents                               7043 non-null   int32
#  3   tenure                                   7043 non-null   int64
#  4   PhoneService                             7043 non-null   int32
#  5   MultipleLines                            7043 non-null   int32
#  6   OnlineSecurity                           7043 non-null   int32
#  7   OnlineBackup                             7043 non-null   int32
#  8   DeviceProtection                         7043 non-null   int32
#  9   TechSupport                              7043 non-null   int32
#  10  StreamingTV                              7043 non-null   int32
#  11  StreamingMovies                          7043 non-null   int32
#  12  Contract                                 7043 non-null   object
#  13  PaperlessBilling                         7043 non-null   int32
#  14  MonthlyCharges                           7043 non-null   float64
#  15  TotalCharges                             7032 non-null   float64
#  16  Churn                                    7043 non-null   object
#  17  gender_Male                              7043 non-null   uint8
#  18  InternetService_Fiber optic              7043 non-null   uint8
#  19  InternetService_No                       7043 non-null   uint8
#  20  PaymentMethod_Bank transfer (automatic)  7043 non-null   uint8
#  21  PaymentMethod_Credit card (automatic)    7043 non-null   uint8
#  22  PaymentMethod_Electronic check           7043 non-null   uint8
#  23  PaymentMethod_Mailed check               7043 non-null   uint8
# dtypes: float64(2), int32(11), int64(2), object(2), uint8(7)
# memory usage: 681.0+ KB

# %%
#y_df = df.pop("Churn").apply(lambda s: 1 if s == "Yes" else 0)
#y_df

# %%
#y_df.dtype

# %%
df.groupby("Churn").count()
# Out:
#        SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# Churn
# No              5174     5174        5174    5174          5174
# Yes             1869     1869        1869    1869          1869
#
#        MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  \
# Churn
# No              5174            5174          5174              5174
# Yes             1869            1869          1869              1869
#
#        TechSupport  ...  PaperlessBilling  MonthlyCharges  TotalCharges  \
# Churn               ...
# No            5174  ...              5174            5174          5163
# Yes           1869  ...              1869            1869          1869
#
#        gender_Male  InternetService_Fiber optic  InternetService_No  \
# Churn
# No            5174                         5174                5174
# Yes           1869                         1869                1869
#
#        PaymentMethod_Bank transfer (automatic)  \
# Churn
# No                                        5174
# Yes                                       1869
#
#        PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# Churn
# No                                      5174                            5174
# Yes                                     1869                            1869
#
#        PaymentMethod_Mailed check
# Churn
# No                           5174
# Yes                          1869
#
# [2 rows x 23 columns]

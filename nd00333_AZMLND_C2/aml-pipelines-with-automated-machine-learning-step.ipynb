# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-automated-machine-learning-step.png)

# %% [markdown]
# # Azure Machine Learning Pipeline with AutoMLStep (Udacity Course 2)
# This notebook demonstrates the use of AutoMLStep in Azure Machine Learning Pipeline.

# %% [markdown]
# ## Introduction
# In this example we showcase how you can use AzureML Dataset to load data for AutoML via AML Pipeline.
#
# If you are using an Azure Machine Learning Notebook VM, you are all set. Otherwise, make sure you have executed the [configuration](https://aka.ms/pl-config) before running this notebook.
#
# In this notebook you will learn how to:
# 1. Create an `Experiment` in an existing `Workspace`.
# 2. Create or Attach existing AmlCompute to a workspace.
# 3. Define data loading in a `TabularDataset`.
# 4. Configure AutoML using `AutoMLConfig`.
# 5. Use AutoMLStep
# 6. Train the model using AmlCompute
# 7. Explore the results.
# 8. Test the best fitted model.

# %% [markdown]
# ## Azure Machine Learning and Pipeline SDK-specific imports

# %%
import logging
import os
import csv

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.18.0

# %% [markdown]
# ## Initialize Workspace
# Initialize a workspace object from persisted configuration. Make sure the config file is present at .\config.json

# %%
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# quick-starts-ws-126085
# aml-quickstarts-126085
# southcentralus
# bc4ac49b-f3f0-45bb-995b-638f2c80696f

# %% [markdown]
# ## Create an Azure ML experiment
# Let's create an experiment named "automlstep-classification" and a folder to hold the training scripts. The script runs will be recorded under the experiment in Azure.
#
# The best practice is to use separate folders for scripts and its dependent files for each step and specify that folder as the `source_directory` for the step. This helps reduce the size of the snapshot created for the step (only the specific folder is snapshotted). Since changes in any files in the `source_directory` would trigger a re-upload of the snapshot, this helps keep the reuse of the step when there are no changes in the `source_directory` of the step.
#
# *Udacity Note:* There is no need to create an Azure ML experiment, this needs to re-use the experiment that was already created

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_name = 'proj2-automl'
project_folder = './pipeline-project'

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Experiment(Name: proj2-automl,
# Workspace: quick-starts-ws-126085)

# %% [markdown]
# ### Create or Attach an AmlCompute cluster
# You will need to create a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) for your AutoML run. In this tutorial, you get the default `AmlCompute` as your training compute resource.
#
# **Udacity Note** There is no need to create a new compute target, it can re-use the previous cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "proj2-cluster"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           max_nodes=4)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 10)
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Found existing cluster, use it.
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# ## Data
#
# **Udacity note:** Make sure the `key` is the same name as the dataset that is uploaded, and that the description matches. If it is hard to find or unknown, loop over the `ws.datasets.keys()` and `print()` them.
# If it *isn't* found because it was deleted, it can be recreated with the link that has the CSV

# %%
# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "BankMarketing Dataset"
description_text = "Bank Marketing DataSet for Udacity Course 2"

if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

if not found:
        # Create AML Dataset and register it into Workspace
        example_data = 'https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv'
        dataset = Dataset.Tabular.from_delimited_files(example_data)        
        #Register Dataset in Workspace
        dataset = dataset.register(workspace=ws,
                                   name=key,
                                   description=description_text)


df = dataset.to_pandas_dataframe()
df.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.040212    257.335205      2.561730    962.174780      0.174780
# std       10.432313    257.331700      2.763646    187.646785      0.496503
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    318.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  32950.000000    32950.000000   32950.000000  32950.000000  32950.000000
# mean       0.076228       93.574243     -40.518680      3.615654   5166.859608
# std        1.572242        0.578636       4.623004      1.735748     72.208448
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# ### Review the Dataset Result
#
# You can peek the result of a TabularDataset at any range using `skip(i)` and `take(j).to_pandas_dataframe()`. Doing so evaluates only `j` records for all the steps in the TabularDataset, which makes it fast even against large datasets.
#
# `TabularDataset` objects are composed of a list of transformation steps (optional).

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   57   technician  married  high.school       no      no  yes   cellular
# 1   55      unknown  married      unknown  unknown     yes   no  telephone
# 2   33  blue-collar  married     basic.9y       no      no   no   cellular
# 3   36       admin.  married  high.school       no      no   no  telephone
# 4   27    housemaid  married  high.school       no     yes   no   cellular
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure         -1.8
# 1   may         thu  ...         2    999         0  nonexistent          1.1
# 2   may         fri  ...         1    999         1      failure         -1.8
# 3   jun         fri  ...         4    999         0  nonexistent          1.4
# 4   jul         fri  ...         2    999         0  nonexistent          1.4
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.299       5099.1  no
# 1          93.994          -36.4      4.860       5191.0  no
# 2          92.893          -46.2      1.313       5099.1  no
# 3          94.465          -41.8      4.967       5228.1  no
# 4          93.918          -42.7      4.963       5228.1  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Train
# This creates a general AutoML settings object.
# **Udacity notes:** These inputs must match what was used when training in the portal. `label_column_name` has to be `y` for example.

# %%
automl_settings = {
    "experiment_timeout_minutes": 20,
    "max_concurrent_iterations": 5,
    "primary_metric" : 'AUC_weighted'
}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=dataset,
                             label_column_name="y",   
                             path = project_folder,
                             enable_early_stopping= True,
                             featurization= 'auto',
                             debug_log = "automl_errors.log",
                             **automl_settings
                            )

# %% [markdown]
# #### Create Pipeline and AutoMLStep
#
# You can define outputs for the AutoMLStep using TrainingOutput.

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %% [markdown]
# Create an AutoMLStep.

# %%
automl_step = AutoMLStep(
    name='automl_module',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %%
pipeline_run = experiment.submit(pipeline)
# Out:
# Created step automl_module [0219105d][c7b9d05f-70ba-4202-ae59-28e0dba43a20], (This step will run and generate new outputs)
# Submitted PipelineRun ace300b7-b141-486a-8c44-a6292fdd780f
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/proj2-automl/runs/ace300b7-b141-486a-8c44-a6292fdd780f?wsid=/subscriptions/bc4ac49b-f3f0-45bb-995b-638f2c80696f/resourcegroups/aml-quickstarts-126085/workspaces/quick-starts-ws-126085

# %%
from azureml.widgets import RunDetails
RunDetails(pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
pipeline_run.wait_for_completion()
# Out:
# PipelineRunId: ace300b7-b141-486a-8c44-a6292fdd780f
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/proj2-automl/runs/ace300b7-b141-486a-8c44-a6292fdd780f?wsid=/subscriptions/bc4ac49b-f3f0-45bb-995b-638f2c80696f/resourcegroups/aml-quickstarts-126085/workspaces/quick-starts-ws-126085
# PipelineRun Status: Running
#
#
# StepRunId: 0f6f71f7-c0df-4792-89e1-8604dab13486
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/proj2-automl/runs/0f6f71f7-c0df-4792-89e1-8604dab13486?wsid=/subscriptions/bc4ac49b-f3f0-45bb-995b-638f2c80696f/resourcegroups/aml-quickstarts-126085/workspaces/quick-starts-ws-126085
# StepRun( automl_module ) Status: NotStarted
# StepRun( automl_module ) Status: Running
#
# StepRun(automl_module) Execution Summary
# =========================================
# StepRun( automl_module ) Status: Finished
# {'runId': '0f6f71f7-c0df-4792-89e1-8604dab13486', 'target': 'proj2-cluster', 'status': 'Completed', 'startTimeUtc': '2020-11-14T11:18:58.510927Z', 'endTimeUtc': '2020-11-14T11:52:15.513095Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '123d661c-fa52-44d4-a0de-7ee3ab753134', 'StepType': 'AutoMLStep', 'azureml.moduleid': 'c7b9d05f-70ba-4202-ae59-28e0dba43a20', 'azureml.nodeid': '0219105d', 'azureml.pipelinerunid': 'ace300b7-b141-486a-8c44-a6292fdd780f', 'num_iterations': '1000', 'training_type': 'TrainFull', 'acquisition_function': 'EI', 'metrics': 'accuracy', 'primary_metric': 'AUC_weighted', 'train_split': '0', 'MaxTimeSeconds': None, 'acquisition_parameter': '0', 'num_cross_validation': None, 'target': 'proj2-cluster', 'RawAMLSettingsString': None, 'AMLSettingsJsonString': '{"path": null, "name": "placeholder", "subscription_id": "bc4ac49b-f3f0-45bb-995b-638f2c80696f", "resource_group": "aml-quickstarts-126085", "workspace_name": "quick-starts-ws-126085", "region": "southcentralus", "compute_target": "proj2-cluster", "spark_service": null, "azure_service": null, "_local_managed_run_id": null, "many_models": false, "pipeline_fetch_max_batch_size": 1, "iterations": 1000, "primary_metric": "AUC_weighted", "task_type": "classification", "data_script": null, "validation_size": 0.0, "n_cross_validations": null, "y_min": null, "y_max": null, "num_classes": null, "featurization": "auto", "_ignore_package_version_incompatibilities": false, "is_timeseries": false, "max_cores_per_iteration": 1, "max_concurrent_iterations": 5, "iteration_timeout_minutes": null, "mem_in_mb": null, "enforce_time_on_windows": false, "experiment_timeout_minutes": 20, "experiment_exit_score": null, "whitelist_models": null, "blacklist_algos": null, "supported_models": ["XGBoostClassifier", "ExtremeRandomTrees", "LogisticRegression", "SVM", "DecisionTree", "RandomForest", "LightGBM", "AveragedPerceptronClassifier", "MultinomialNaiveBayes", "KNN", "GradientBoosting", "TensorFlowLinearClassifier", "BernoulliNaiveBayes", "SGD", "TensorFlowDNN", "LinearSVM"], "auto_blacklist": true, "blacklist_samples_reached": false, "exclude_nan_labels": true, "verbosity": 20, "_debug_log": "automl_errors.log", "show_warnings": false, "model_explainability": true, "service_url": null, "sdk_url": null, "sdk_packages": null, "enable_onnx_compatible_models": false, "enable_split_onnx_featurizer_estimator_models": false, "vm_type": "STANDARD_DS12_V2", "telemetry_verbosity": 20, "send_telemetry": true, "enable_dnn": false, "scenario": "SDK-1.13.0", "environment_label": null, "force_text_dnn": false, "enable_feature_sweeping": true, "enable_early_stopping": true, "early_stopping_n_iters": 10, "metrics": null, "enable_ensembling": true, "enable_stack_ensembling": true, "ensemble_iterations": 15, "enable_tf": false, "enable_subsampling": null, "subsample_seed": null, "enable_nimbusml": false, "enable_streaming": false, "force_streaming": false, "track_child_runs": true, "allowed_private_models": [], "label_column_name": "y", "weight_column_name": null, "cv_split_column_names": null, "enable_local_managed": false, "cost_mode": 1, "lag_length": 0, "metric_operation": "maximize", "preprocess": true}', 'DataPrepJsonString': '{\\"training_data\\": {\\"datasetId\\": \\"4060263c-69e8-4821-98c2-a5fd61ecc109\\"}, \\"datasets\\": 0}', 'EnableSubsampling': 'False', 'runTemplate': 'AutoML', 'Orchestrator': 'automl', 'ClientType': 'Others', '_aml_system_scenario_identification': 'Remote.Parent', 'root_attribution': 'azureml.StepRun', 'snapshotId': '123d661c-fa52-44d4-a0de-7ee3ab753134', 'SetupRunId': '0f6f71f7-c0df-4792-89e1-8604dab13486_setup', 'SetupRunContainerId': 'dcid.0f6f71f7-c0df-4792-89e1-8604dab13486_setup', 'ClientSdkVersion': '1.18.0', 'FeaturizationRunJsonPath': 'featurizer_container.json', 'FeaturizationRunId': '0f6f71f7-c0df-4792-89e1-8604dab13486_featurize', 'ProblemInfoJsonString': '{"dataset_num_categorical": 0, "is_sparse": true, "subsampling": fal ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'ace300b7-b141-486a-8c44-a6292fdd780f', 'status': 'Completed', 'startTimeUtc': '2020-11-14T11:18:16.009323Z', 'endTimeUtc': '2020-11-14T11:54:37.284787Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlstrg126085.blob.core.windows.net/azureml/ExperimentRun/dcid.ace300b7-b141-486a-8c44-a6292fdd780f/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=C%2BabMU8inby1dSroAHtvmf6g28lawLVMvWlLVGTCaFc%3D&st=2020-11-14T11%3A08%3A38Z&se=2020-11-14T19%3A18%3A38Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlstrg126085.blob.core.windows.net/azureml/ExperimentRun/dcid.ace300b7-b141-486a-8c44-a6292fdd780f/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=Ve7S33njMxwHudftmX101Kr%2F55yf0j9QHtdN0eksIbk%3D&st=2020-11-14T11%3A08%3A38Z&se=2020-11-14T19%3A18%3A38Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlstrg126085.blob.core.windows.net/azureml/ExperimentRun/dcid.ace300b7-b141-486a-8c44-a6292fdd780f/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=0XN4mQ86cvhG7GJbA23Grf3hBwE5HkbroP2tO0t4U54%3D&st=2020-11-14T11%3A08%3A38Z&se=2020-11-14T19%3A18%3A38Z&sp=r'}}
# 'Finished'

# %% [markdown]
# ## Examine Results
#
# ### Retrieve the metrics of all child runs
# Outputs of above run can be used as inputs of other steps in pipeline. In this tutorial, we will examine the outputs by retrieve output data and running some tests.

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('.', show_progress=True)
# Out:
# Downloading azureml/0f6f71f7-c0df-4792-89e1-8604dab13486/metrics_data
# Downloaded azureml/0f6f71f7-c0df-4792-89e1-8604dab13486/metrics_data, 1 files out of an estimated total of 1

# %%
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
#                                  0f6f71f7-c0df-4792-89e1-8604dab13486_21  \
# balanced_accuracy                                   [0.7220819046878098]
# log_loss                                            [0.5312072706137217]
# f1_score_weighted                                   [0.7574610586763234]
# precision_score_micro                               [0.7040971168437026]
# f1_score_micro                                      [0.7040971168437026]
# average_precision_score_weighted                    [0.9204293715196785]
# average_precision_score_macro                       [0.7129301301492308]
# average_precision_score_micro                       [0.8323439499916359]
# norm_macro_recall                                   [0.4441638093756195]
# recall_score_micro                                  [0.7040971168437026]
# AUC_weighted                                         [0.861480197166975]
# precision_score_weighted                            [0.8756284739379083]
# recall_score_macro                                  [0.7220819046878098]
# weighted_accuracy                                   [0.6996319805022906]
# f1_score_macro                                      [0.5840791028109981]
# accuracy                                            [0.7040971168437026]
# precision_score_macro                               [0.5969717521527215]
# matthews_correlation                                 [0.293500742206834]
# AUC_micro                                           [0.8309567307803012]
# AUC_macro                                           [0.8614801971669751]
# recall_score_weighted                               [0.7040971168437026]
#
#                                  0f6f71f7-c0df-4792-89e1-8604dab13486_30  \
# balanced_accuracy                                   [0.5675677553084485]
# log_loss                                            [0.2292238675952688]
# f1_score_weighted                                   [0.8675066697235122]
# precision_score_micro                               [0.9007587253414264]
# f1_score_micro                                      [0.9007587253414264]
# average_precision_score_weighted                    [0.9470311070568083]
# average_precision_score_macro                       [0.7969693494944702]
# average_precision_score_micro                       [0.9747660084035891]
# norm_macro_recall                                    [0.135135510616897]
# recall_score_micro                                  [0.9007587253414264]
# AUC_weighted                                        [0.9281958591971429]
# precision_score_weighted                            [0.8959103648683194]
# recall_score_macro                                  [0.5675677553084485]
# weighted_accuracy                                   [0.9834810305373748]
# f1_score_macro                                      [0.5923432191895104]
# accuracy                                            [0.9007587253414264]
# precision_score_macro                               [0.8758500772797526]
# matthews_correlation                                [0.3187183462199802]
# AUC_micro                                           [0.9737530308717166]
# AUC_macro                                           [0.9281958591971429]
# recall_score_weighted                               [0.9007587253414264]
#
#                                  0f6f71f7-c0df-4792-89e1-8604dab13486_3  \
# balanced_accuracy                                  [0.8487844704147657]
# log_loss                                           [0.3724055159007936]
# f1_score_weighted                                  [0.8728527744232011]
# precision_score_micro                              [0.8534142640364188]
# f1_score_micro                                     [0.8534142640364188]
# average_precision_score_weighted                   [0.9376121821823153]
# average_precision_score_macro                      [0.7589900830738389]
# average_precision_score_micro                      [0.8991166534038151]
# norm_macro_recall                                  [0.6975689408295314]
# recall_score_micro                                 [0.8534142640364188]
# AUC_weighted                                       [0.9190168695945333]
# precision_score_weighted                           [0.9152062098157044]
# recall_score_macro                                 [0.8487844704147657]
# weighted_accuracy                                  [0.8545637165588769]
# f1_score_macro                                     [0.7374187933360008]
# accuracy                                           [0.8534142640364188]
# precision_score_macro                              [0.6999446221350052]
# matthews_correlation                               [0.5281574732734101]
# AUC_micro                                          [0.9183609690499929]
# AUC_macro                                          [0.9190168695945333]
# recall_score_weighted                              [0.8534142640364188]
#
#                                  0f6f71f7-c0df-4792-89e1-8604dab13486_0  \
# balanced_accuracy                                  [0.7513392683482543]
# log_loss                                          [0.17775706110025447]
# f1_score_weighted                                  [0.9091539479147899]
# precision_score_micro                              [0.9116843702579667]
# f1_score_micro                                     [0.9116843702579667]
# average_precision_score_weighted                   [0.9531771295804466]
# average_precision_score_macro                      [0.8151093723721079]
# average_precision_score_micro                      [0.9806603102489483]
# norm_macro_recall                                  [0.5026785366965085]
# recall_score_micro                                 [0.9116843702579667]
# AUC_weighted                                       [0.9450464668693167]
# precision_score_weighted                           [0.9072720074188747]
# recall_score_macro                                 [0.7513392683482543]
# weighted_accuracy                                  [0.9514937218005303]
# f1_score_macro                                     [0.7653697272147331]
# accuracy                                           [0.9116843702579667]
# precision_score_macro                              [0.7819118765348991]
# matthews_correlation                               [0.5323740218566827]
# AUC_micro                                           [0.979695082216353]
# AUC_macro                                          [0.9450464668693166]
# recall_score_weighted                              [0.9116843702579667]
#
#                                  0f6f71f7-c0df-4792-89e1-8604dab13486_28  \
# balanced_accuracy                                   [0.6855164518835892]
# log_loss                                           [0.22016323531640344]
# f1_score_weighted                                    [0.898513121045057]
# precision_score_micro                               [0.9083459787556905]
# f1_score_micro                                      [0.9083459787556905]
# average_precision_score_weighted                    [0.9473883104711966]
# average_precision_score_macro                       [0.7969160199391022]
# average_precision_score_micro                       [0.9771015060033911]
# norm_macro_recall                                  [0.37103290376717846]
# recall_score_micro                                  [0.9083459787556905]
# AUC_weighted                                        [0.9298458637354657]
# precision_score_weighted                             [0.896276493147234]
# recall_score_macro                                  [0.6855164518835892]
# weighted_accuracy                                   [0.9636685228413189]
# f1_score_macro                                      [0.7214524367768216]
# accuracy                                            [0.9083459787556905]
# precision_score_macro                               [0.7876086244823646]
# matthews_correlation                                [0.4619789239568743]
# AUC_micro                                           [0.9760192133664609]
# AUC_macro                                           [0.9298458637354658]
# recall_score_weighted                               [0.9083459787556905]
#
#                                  0f6f71f7-c0df-4792-89e1-8604dab13486_5  \
# balanced_accuracy                                  [0.5861721006136924]
# log_loss                                           [0.2442606150560668]
# f1_score_weighted                                   [0.872739945318913]
# precision_score_micro                              [0.9001517450682853]
# f1_score_micro                                     [0.9001517450682853]
# average_precision_score_weighted                   [0.9315568893749121]
# average_precision_score_macro                      [0.7427903820139726]
# average_precision_score_micro                      [0.9688287107163841]
# norm_macro_recall                                  [0.1723442012273848]
# recall_score_micro                                 [0.9001517450682853]
# AUC_weighted                                       [0.8964808547607008]
# precision_score_weighted                           [0.8840533097056155]
# recall_score_macro                                 [0.5861721006136924]
# weighted_accuracy                                  [0.9781043977806846]
# f1_score_macro                                     [0.6178600472856574]
# accuracy                                           [0.9001517450682853]
# precision_score_macro                              [0.8092102202104395]
# matthews_correlation                               [0.3264677270834346]
# AUC_micro                                          [0.9674386860120521]
# AUC_macro                                          [0.8964808547607007]
# recall_score_weighted                              [0.9001517450682853]
#
#                                  0f6f71f7-c0df-4792-89e1-8604dab13486_6  \
# balanced_accuracy                                  [0.5929351279158724]
# log_loss                                          [0.23645540101980647]
# f1_score_weighted                                  [0.8742062417853778]
# precision_score_micro                              [0.8995447647951441]
# f1_score_micro                                     [0.8995447647951441]
# average_precision_score_weighted                   [0.9324602941666443]
# average_precision_score_macro                      [0.7442237019682773]
# average_precision_score_micro                      [0.9695227511129372]
# norm_macro_recall                                 [0.18587025583174488]
# recall_score_micro                                 [0.8995447647951441]
# AUC_weighted                                       [0.9030188182948131]
# precision_score_weighted                             [0.88123145543058]
# recall_score_macro                                 [0.5929351279158724]
# weighted_accuracy                                   [0.975667643981923]
# f1_score_macro                                     [0.6259663822605774]
# accuracy                                           [0.8995447647951441]
# precision_score_macro                              [0.7915243059187207]
# matthews_correlation                              [0.32919810850697334]
# AUC_micro                                          [0.9685430401053696]
# AUC_macro                                          [0.9030188182948131]
# recall_score_weighted                              [0.8995447647951441]
#
#                                  0f6f71f7-c0df-4792-89e1-8604dab13486_16  \
# balanced_accuracy                                   [0.7258172222870554]
# log_loss                                            [0.5341635563199723]
# f1_score_weighted                                    [0.759398156585292]
# precision_score_micro                               [0.7065250379362671]
# f1_score_micro                                      [0.7065250379362671]
# average_precision_score_weighted                     [0.914149876751836]
# average_precision_score_macro                       [0.6938321849583192]
# average_precision_score_micro                       [0.8252772715869998]
# norm_macro_recall                                   [0.4516344445741107]
# recall_score_micro                                  [0.7065250379362671]
# AUC_weighted                                        [0.8472104133208113]
# precision_score_weighted                            [0.8768169965009414]
# recall_score_macro                                  [0.7258172222870554]
# weighted_accuracy                                   [0.7017353104067231]
# f1_score_macro                                      [0.5867333233981185]
# accuracy                                            [0.7065250379362671]
# precision_score_macro                               [0.5987604587934878]
# matthews_correlation                               [0.29867582745539095]
# AUC_micro                                           [0.8173143195304422]
# AUC_macro                                           [0.8472104133208113]
# recall_score_weighted                               [0.7065250379362671]
#
#                                  0f6f71f7-c0df-4792-89e1-8604dab13486_13  \
# balanced_accuracy                                   [0.7502028352477647]
# log_loss                                            [0.6144272733487015]
# f1_score_weighted                                   [0.8079298900661662]
# precision_score_micro                               [0.7708649468892261]
# f1_score_micro                                      [0.7708649468892261]
# average_precision_score_weighted                    [0.9107692497218001]
# average_precision_score_macro                       [0.6971870701342704]
# average_precision_score_micro                       [0.7868296267004975]
# norm_macro_recall                                   [0.5004056704955293]
# recall_score_micro                                  [0.7708649468892261]
# AUC_weighted                                        [0.8305209624208341]
# precision_score_weighted                             [0.882375179784918]
# recall_score_macro                                  [0.7502028352477647]
# weighted_accuracy                                   [0.7759947903091381]
# f1_score_macro                                      [0.6359243370653751]
# accuracy                                            [0.7708649468892261]
# precision_score_macro                               [0.6236350114416476]
# matthews_correlation                                [0.3517603183907477]
# AUC_micro                                           [0.8256152122703964]
# AUC_macro                                           [0.8305209624208341]
# recall_score_weighted                               [0.7708649468892261]
#
#                                  0f6f71f7-c0df-4792-89e1-8604dab13486_25  ...  \
# balanced_accuracy                                     [0.75895670439958]  ...
# log_loss                                           [0.19370054320418742]  ...
# f1_score_weighted                                   [0.9106208860084958]  ...
# precision_score_micro                               [0.9125948406676783]  ...
# f1_score_micro                                      [0.9125948406676783]  ...
# average_precision_score_weighted                    [0.9516558858697237]  ...
# average_precision_score_macro                       [0.8096965049514568]  ...
# average_precision_score_micro                       [0.9794040437599212]  ...
# norm_macro_recall                                   [0.5179134087991599]  ...
# recall_score_micro                                  [0.9125948406676783]  ...
# AUC_weighted                                        [0.9423697825495002]  ...
# precision_score_weighted                            [0.9090583667022298]  ...
# recall_score_macro                                    [0.75895670439958]  ...
# weighted_accuracy                                   [0.9507390340617803]  ...
# f1_score_macro                                      [0.7704152731326646]  ...
# accuracy                                            [0.9125948406676783]  ...
# precision_score_macro                               [0.7834644232348487]  ...
# matthews_correlation                                [0.5418671898368607]  ...
# AUC_micro                                           [0.9783902127884941]  ...
# AUC_macro                                           [0.9423697825495001]  ...
# recall_score_weighted                               [0.9125948406676783]  ...
#
#                                  0f6f71f7-c0df-4792-89e1-8604dab13486_18  \
# balanced_accuracy                                   [0.8264086861647837]
# log_loss                                           [0.41981171462576283]
# f1_score_weighted                                   [0.8656495932716218]
# precision_score_micro                               [0.8452200303490136]
# f1_score_micro                                      [0.8452200303490137]
# average_precision_score_weighted                    [0.9351064976621543]
# average_precision_score_macro                       [0.7579839921162544]
# average_precision_score_micro                        [0.876345809781613]
# norm_macro_recall                                   [0.6528173723295674]
# recall_score_micro                                  [0.8452200303490136]
# AUC_weighted                                        [0.9036634453835996]
# precision_score_weighted                            [0.9079326145966337]
# recall_score_macro                                  [0.8264086861647837]
# weighted_accuracy                                   [0.8498903782717077]
# f1_score_macro                                      [0.7221375262575862]
# accuracy                                            [0.8452200303490136]
# precision_score_macro                               [0.6876632767928365]
# matthews_correlation                               [0.49499464085716277]
# AUC_micro                                           [0.8997655435075448]
# AUC_macro                                           [0.9036634453835994]
# recall_score_weighted                               [0.8452200303490136]
#
#                                  0f6f71f7-c0df-4792-89e1-8604dab13486_10  \
# balanced_accuracy                                                  [0.5]
# log_loss                                           [0.27408684843995673]
# f1_score_weighted                                   [0.8353395018439429]
# precision_score_micro                               [0.8880121396054628]
# f1_score_micro                                      [0.8880121396054628]
# average_precision_score_weighted                    [0.9217075397225707]
# average_precision_score_macro                        [0.726096891674438]
# average_precision_score_micro                       [0.9593686512320646]
# norm_macro_recall                                                  [0.0]
# recall_score_micro                                  [0.8880121396054628]
# AUC_weighted                                        [0.8571317428827054]
# precision_score_weighted                             [0.788565560086672]
# recall_score_macro                                                 [0.5]
# weighted_accuracy                                   [0.9843450583187134]
# f1_score_macro                                      [0.4703423886834914]
# accuracy                                            [0.8880121396054628]
# precision_score_macro                               [0.4440060698027314]
# matthews_correlation                                               [0.0]
# AUC_micro                                           [0.9590432001400014]
# AUC_macro                                           [0.8571317428827057]
# recall_score_weighted                               [0.8880121396054628]
#
#                                  0f6f71f7-c0df-4792-89e1-8604dab13486_24  \
# balanced_accuracy                                                  [0.5]
# log_loss                                            [0.3497026042726693]
# f1_score_weighted                                   [0.8353395018439429]
# precision_score_micro                               [0.8880121396054628]
# f1_score_micro                                      [0.8880121396054628]
# average_precision_score_weighted                    [0.9189380242550522]
# average_precision_score_macro                       [0.7103613738321392]
# average_precision_score_micro                       [0.9607664043621833]
# norm_macro_recall                                                  [0.0]
# recall_score_micro                                  [0.8880121396054628]
# AUC_weighted                                        [0.8802313433250533]
# precision_score_weighted                             [0.788565560086672]
# recall_score_macro                                                 [0.5]
# weighted_accuracy                                   [0.9843450583187134]
# f1_score_macro                                      [0.4703423886834914]
# accuracy                                            [0.8880121396054628]
# precision_score_macro                               [0.4440060698027314]
# matthews_correlation                                               [0.0]
# AUC_micro                                           [0.9636375526444859]
# AUC_macro                                           [0.8802313433250533]
# recall_score_weighted                               [0.8880121396054628]
#
#                                  0f6f71f7-c0df-4792-89e1-8604dab13486_38  \
# balanced_accuracy                                   [0.7181956183881729]
# log_loss                                           [0.20252538808893247]
# f1_score_weighted                                   [0.9070553307236097]
# precision_score_micro                               [0.9138088012139606]
# f1_score_micro                                      [0.9138088012139606]
# average_precision_score_weighted                    [0.9546534578490573]
# average_precision_score_macro                       [0.8218077494192368]
# average_precision_score_micro                       [0.9807816803563876]
# norm_macro_recall                                  [0.43639123677634584]
# recall_score_micro                                  [0.9138088012139606]
# AUC_weighted                                        [0.9452113283948971]
# precision_score_weighted                            [0.9047611150863775]
# recall_score_macro                                  [0.7181956183881729]
# weighted_accuracy                                   [0.9623742632625392]
# f1_score_macro                                      [0.7500678394160896]
# accuracy                                            [0.9138088012139606]
# precision_score_macro                               [0.7996023267762398]
# matthews_correlation                                 [0.511358641117864]
# AUC_micro                                           [0.9798506496945526]
# AUC_macro                                           [0.9452113283948971]
# recall_score_weighted                               [0.9138088012139606]
#
#                                  0f6f71f7-c0df-4792-89e1-8604dab13486_7  \
# balanced_accuracy                                  [0.6003576013203741]
# log_loss                                          [0.23213927964116182]
# f1_score_weighted                                  [0.8738813848292685]
# precision_score_micro                              [0.8959028831562974]
# f1_score_micro                                     [0.8959028831562974]
# average_precision_score_weighted                   [0.9375084501055427]
# average_precision_score_macro                       [0.755719704021519]
# average_precision_score_micro                      [0.9689409485665729]
# norm_macro_recall                                 [0.20071520264074816]
# recall_score_micro                                 [0.8959028831562974]
# AUC_weighted                                       [0.9232588122190176]
# precision_score_weighted                           [0.8737524200502865]
# recall_score_macro                                 [0.6003576013203741]
# weighted_accuracy                                  [0.9692787822715527]
# f1_score_macro                                     [0.6322119804420869]
# accuracy                                           [0.8959028831562974]
# precision_score_macro                              [0.7522100720630132]
# matthews_correlation                               [0.3181898669730556]
# AUC_micro                                            [0.97076482738135]
# AUC_macro                                          [0.9232588122190175]
# recall_score_weighted                              [0.8959028831562974]
#
#                                  0f6f71f7-c0df-4792-89e1-8604dab13486_22  \
# balanced_accuracy                                   [0.7378030256720886]
# log_loss                                            [0.5669428191995315]
# f1_score_weighted                                   [0.7789456041318004]
# precision_score_micro                               [0.7320182094081943]
# f1_score_micro                                      [0.7320182094081943]
# average_precision_score_weighted                    [0.9156000029996122]
# average_precision_score_macro                       [0.7192818554960323]
# average_precision_score_micro                       [0.8084557596832637]
# norm_macro_recall                                   [0.4756060513441771]
# recall_score_micro                                  [0.7320182094081943]
# AUC_weighted                                         [0.832128825389416]
# precision_score_weighted                            [0.8795412466740833]
# recall_score_macro                                  [0.7378030256720886]
# weighted_accuracy                                   [0.7305819960065015]
# f1_score_macro                                      [0.6062933044076838]
# accuracy                                            [0.7320182094081943]
# precision_score_macro                                [0.608162537113739]
# matthews_correlation                                [0.3207577190966211]
# AUC_micro                                           [0.8275794704350408]
# AUC_macro                                           [0.8321288253894159]
# recall_score_weighted                               [0.7320182094081943]
#
#                                  0f6f71f7-c0df-4792-89e1-8604dab13486_19  \
# balanced_accuracy                                                  [0.5]
# log_loss                                            [0.2650379986841843]
# f1_score_weighted                                   [0.8353395018439429]
# precision_score_micro                               [0.8880121396054628]
# f1_score_micro                                      [0.8880121396054628]
# average_precision_score_weighted                    [0.9237812221571269]
# average_precision_score_macro                       [0.7128627425892439]
# average_precision_score_micro                       [0.9670392365859944]
# norm_macro_recall                                                  [0.0]
# recall_score_micro                                  [0.8880121396054628]
# AUC_weighted                                        [0.8957246219762265]
# precision_score_weighted                             [0.788565560086672]
# recall_score_macro                                                 [0.5]
# weighted_accuracy                                   [0.9843450583187134]
# f1_score_macro                                      [0.4703423886834914]
# accuracy                                            [0.8880121396054628]
# precision_score_macro                               [0.4440060698027314]
# matthews_correlation                                               [0.0]
# AUC_micro                                           [0.9667190597792672]
# AUC_macro                                           [0.8957246219762265]
# recall_score_weighted                               [0.8880121396054628]
#
#                                  0f6f71f7-c0df-4792-89e1-8604dab13486_4  \
# balanced_accuracy                                  [0.6447072040781925]
# log_loss                                           [0.3237422891566155]
# f1_score_weighted                                  [0.8865807020316077]
# precision_score_micro                              [0.9010622154779969]
# f1_score_micro                                     [0.9010622154779969]
# average_precision_score_weighted                   [0.9365716431859008]
# average_precision_score_macro                      [0.7599949834402286]
# average_precision_score_micro                       [0.968691783823596]
# norm_macro_recall                                   [0.289414408156385]
# recall_score_micro                                 [0.9010622154779969]
# AUC_weighted                                       [0.9159863813265611]
# precision_score_weighted                           [0.8844121806068286]
# recall_score_macro                                 [0.6447072040781925]
# weighted_accuracy                                  [0.9647082305228422]
# f1_score_macro                                        [0.6808627582404]
# accuracy                                           [0.9010622154779969]
# precision_score_macro                              [0.7661506829246687]
# matthews_correlation                                [0.392499279945991]
# AUC_micro                                          [0.9697889615249111]
# AUC_macro                                          [0.9159863813265611]
# recall_score_weighted                              [0.9010622154779969]
#
#                                  0f6f71f7-c0df-4792-89e1-8604dab13486_33  \
# balanced_accuracy                                   [0.5804223233619896]
# log_loss                                           [0.23272289656454062]
# f1_score_weighted                                   [0.8712812338562995]
# precision_score_micro                               [0.9004552352048558]
# f1_score_micro                                      [0.9004552352048558]
# average_precision_score_weighted                    [0.9412040743608816]
# average_precision_score_macro                       [0.7738442358930686]
# average_precision_score_micro                       [0.9736652308713766]
# norm_macro_recall                                  [0.16084464672397925]
# recall_score_micro                                  [0.9004552352048558]
# AUC_weighted                                        [0.9208173797390742]
# precision_score_weighted                            [0.8867903401078067]
# recall_score_macro                                  [0.5804223233619896]
# weighted_accuracy                                   [0.9799107504716511]
# f1_score_macro                                       [0.610449340680571]
# accuracy                                            [0.9004552352048558]
# precision_score_macro                                [0.825704436675719]
# matthews_correlation                               [0.32369063951105753]
# AUC_micro                                           [0.9724187795459622]
# AUC_macro                                           [0.9208173797390742]
# recall_score_weighted                               [0.9004552352048558]
#
#                                  0f6f71f7-c0df-4792-89e1-8604dab13486_37
# balanced_accuracy                                   [0.7232739090890568]
# log_loss                                           [0.18323859937810894]
# f1_score_weighted                                   [0.9081434651080684]
# precision_score_micro                               [0.9144157814871017]
# f1_score_micro                                      [0.9144157814871017]
# average_precision_score_weighted                    [0.9550961558092025]
# average_precision_score_macro                       [0.8230679006789022]
# average_precision_score_micro                        [0.981157413234223]
# norm_macro_recall                                   [0.4465478181781135]
# recall_score_micro                                  [0.9144157814871017]
# AUC_weighted                                        [0.9466432155777471]
# precision_score_weighted                            [0.9058258332489991]
# recall_score_macro                                  [0.7232739090890568]
# weighted_accuracy                                   [0.9618711381033722]
# f1_score_macro                                       [0.753928917212026]
# accuracy                                            [0.9144157814871017]
# precision_score_macro                               [0.8002272868796314]
# matthews_correlation                                [0.5178143294920177]
# AUC_micro                                            [0.980240996037128]
# AUC_macro                                           [0.9466432155777471]
# recall_score_weighted                               [0.9144157814871017]
#
# [21 rows x 36 columns]

# %% [markdown]
# ### Retrieve the Best Model

# %%
# Retrieve best model from Pipeline Run
best_model_output = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model_output.download('.', show_progress=True)
# Out:
# Downloading azureml/0f6f71f7-c0df-4792-89e1-8604dab13486/model_data
# Downloaded azureml/0f6f71f7-c0df-4792-89e1-8604dab13486/model_data, 1 files out of an estimated total of 1

# %%
import pickle

with open(best_model_output._path_on_datastore, "rb" ) as f:
    best_model = pickle.load(f)
best_model
# Out:
# PipelineWithYTransformations(Pipeline={'memory': None,
#                                        'steps': [('datatransformer',
#                                                   DataTransformer(enable_dnn=None,
#                                                                   enable_feature_sweeping=None,
#                                                                   feature_sweeping_config=None,
#                                                                   feature_sweeping_timeout=None,
#                                                                   featurization_config=None,
#                                                                   force_text_dnn=None,
#                                                                   is_cross_validation=None,
#                                                                   is_onnx_compatible=None,
#                                                                   logger=None,
#                                                                   observer=None,
#                                                                   task=None,
#                                                                   working_dir=None))...
#                                                                                                                                      min_weight_fraction_leaf=0.0,
#                                                                                                                                      n_estimators=10,
#                                                                                                                                      n_jobs=1,
#                                                                                                                                      oob_score=True,
#                                                                                                                                      random_state=None,
#                                                                                                                                      verbose=0,
#                                                                                                                                      warm_start=False))],
#                                                                                                       verbose=False))],
#                                                                                 flatten_transform=None,
#                                                                                 weights=[0.4,
#                                                                                          0.06666666666666667,
#                                                                                          0.26666666666666666,
#                                                                                          0.06666666666666667,
#                                                                                          0.06666666666666667,
#                                                                                          0.06666666666666667,
#                                                                                          0.06666666666666667]))],
#                                        'verbose': False},
#                              y_transformer={},
#                              y_transformer_name='LabelEncoder')

# %%
best_model.steps
# Out:
# [('datatransformer',
#   DataTransformer(enable_dnn=None, enable_feature_sweeping=None,
#                   feature_sweeping_config=None, feature_sweeping_timeout=None,
#                   featurization_config=None, force_text_dnn=None,
#                   is_cross_validation=None, is_onnx_compatible=None, logger=None,
#                   observer=None, task=None, working_dir=None)),
#  ('prefittedsoftvotingclassifier',
#   PreFittedSoftVotingClassifier(classification_labels=None,
#                                 estimators=[('0',
#                                              Pipeline(memory=None,
#                                                       steps=[('maxabsscaler',
#                                                               MaxAbsScaler(copy=True)),
#                                                              ('lightgbmclassifier',
#                                                               LightGBMClassifier(boosting_type='gbdt',
#                                                                                  class_weight=None,
#                                                                                  colsample_bytree=1.0,
#                                                                                  importance_type='split',
#                                                                                  learning_rate=0.1,
#                                                                                  max_depth=-1,
#                                                                                  min_child_samples=20,
#                                                                                  min_child_weight=0.001,
#                                                                                  min_spl...
#                                                                                      min_samples_leaf=0.035789473684210524,
#                                                                                      min_samples_split=0.01,
#                                                                                      min_weight_fraction_leaf=0.0,
#                                                                                      n_estimators=10,
#                                                                                      n_jobs=1,
#                                                                                      oob_score=True,
#                                                                                      random_state=None,
#                                                                                      verbose=0,
#                                                                                      warm_start=False))],
#                                                       verbose=False))],
#                                 flatten_transform=None,
#                                 weights=[0.4, 0.06666666666666667,
#                                          0.26666666666666666, 0.06666666666666667,
#                                          0.06666666666666667, 0.06666666666666667,
#                                          0.06666666666666667]))]

# %% [markdown]
# ### Test the Model
# #### Load Test Data
# For the test data, it should have the same preparation step as the train data. Otherwise it might get failed at the preprocessing step.

# %%
dataset_test = Dataset.Tabular.from_delimited_files(path='https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv')
df_test = dataset_test.to_pandas_dataframe()
df_test = df_test[pd.notnull(df_test['y'])]

y_test = df_test['y']
X_test = df_test.drop(['y'], axis=1)

# %% [markdown]
# #### Testing Our Best Fitted Model
#
# We will use confusion matrix to see how our model works.

# %%
from sklearn.metrics import confusion_matrix
ypred = best_model.predict(X_test)
cm = confusion_matrix(y_test, ypred)

# %%
# Visualize the confusion matrix
pd.DataFrame(cm).style.background_gradient(cmap='Blues', low=0, high=0.9)
# Out:
# <style  type="text/css" >
#     #T_73a7e3a0_2670_11eb_aab8_000d3aec0864row0_col0 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_73a7e3a0_2670_11eb_aab8_000d3aec0864row0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_73a7e3a0_2670_11eb_aab8_000d3aec0864row1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_73a7e3a0_2670_11eb_aab8_000d3aec0864row1_col1 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }</style><table id="T_73a7e3a0_2670_11eb_aab8_000d3aec0864" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_73a7e3a0_2670_11eb_aab8_000d3aec0864level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_73a7e3a0_2670_11eb_aab8_000d3aec0864row0_col0" class="data row0 col0" >28997</td>
#                         <td id="T_73a7e3a0_2670_11eb_aab8_000d3aec0864row0_col1" class="data row0 col1" >261</td>
#             </tr>
#             <tr>
#                         <th id="T_73a7e3a0_2670_11eb_aab8_000d3aec0864level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_73a7e3a0_2670_11eb_aab8_000d3aec0864row1_col0" class="data row1 col0" >1201</td>
#                         <td id="T_73a7e3a0_2670_11eb_aab8_000d3aec0864row1_col1" class="data row1 col1" >2491</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Publish and run from REST endpoint
#
# Run the following code to publish the pipeline to your workspace. In your workspace in the portal, you can see metadata for the pipeline including run history and durations. You can also run the pipeline manually from the portal.
#
# Additionally, publishing the pipeline enables a REST endpoint to rerun the pipeline from any HTTP library on any platform.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="Bankmarketing Train", description="Training bankmarketing pipeline", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: Bankmarketing Train,
# Id: c9a34cc0-7980-478f-824e-747495ffc56b,
# Status: Active,
# Endpoint: https://southcentralus.api.azureml.ms/pipelines/v1.0/subscriptions/bc4ac49b-f3f0-45bb-995b-638f2c80696f/resourceGroups/aml-quickstarts-126085/providers/Microsoft.MachineLearningServices/workspaces/quick-starts-ws-126085/PipelineRuns/PipelineSubmit/c9a34cc0-7980-478f-824e-747495ffc56b)

# %% [markdown]
# Authenticate once again, to retrieve the `auth_header` so that the endpoint can be used

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Get the REST url from the endpoint property of the published pipeline object. You can also find the REST url in your workspace in the portal. Build an HTTP POST request to the endpoint, specifying your authentication header. Additionally, add a JSON payload object with the experiment name and the batch size parameter. As a reminder, the process_count_per_node is passed through to ParallelRunStep because you defined it is defined as a PipelineParameter object in the step configuration.
#
# Make the request to trigger the run. Access the Id key from the response dict to get the value of the run id.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "pipeline-rest-endpoint"}
                        )

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)
# Out:
# Submitted pipeline run:  a05949c5-cbf3-45d6-acb0-e1806c46570e

# %% [markdown]
# Use the run id to monitor the status of the new run. This will take another 10-15 min to run and will look similar to the previous pipeline run, so if you don't need to see another pipeline run, you can skip watching the full output.

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["pipeline-rest-endpoint"], run_id)
RunDetails(published_pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
